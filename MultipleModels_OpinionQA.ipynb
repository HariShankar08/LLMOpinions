# %% [markdown]
# <a href="https://www.kaggle.com/code/hshankar08/multiplemodelsopinionqa?scriptVersionId=203488445" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/openqa-questions/openqa_questions/HAVEKIDS1_W50.json
# /kaggle/input/openqa-questions/openqa_questions/WORRYD_W26.json
# /kaggle/input/openqa-questions/openqa_questions/FAMSURV9a_W50.json
# /kaggle/input/openqa-questions/openqa_questions/PAR2_W50.json
# /kaggle/input/openqa-questions/openqa_questions/BETTERPOL1F1G_W36.json
# /kaggle/input/openqa-questions/openqa_questions/MESUM2_FF_W29.json
# /kaggle/input/openqa-questions/openqa_questions/RACESURV20_W43.json
# /kaggle/input/openqa-questions/openqa_questions/CONFd_F1_W42.json
# /kaggle/input/openqa-questions/openqa_questions/SCM5i_W42.json
# /kaggle/input/openqa-questions/openqa_questions/RACESURV28e_W43.json
# /kaggle/input/openqa-questions/openqa_questions/CONTROLGRPa_W49.json
# /kaggle/input/openqa-questions/openqa_questions/PQ3_F2Ca_W42.json
# /kaggle/input/openqa-questions/openqa_questions/REASONGUND_W26.json
# /kaggle/input/openqa-questions/openqa_questions/RQ5_F1B_W42.json
# /kaggle/input/openqa-questions/openqa_questions/EAT3H_W34.json
# /kaggle/input/openqa-questions/openqa_questions/SUPERPWR_W92.json
# /kaggle/input/openqa-questions/openqa_questions/CONTROLGRPd_W49.json
# /kaggle/input/openqa-questions/openqa_questions/HARASS1F1a_W41.json
# /kaggle/input/openqa-questions/openqa_questions/SOLVPROBc_W41.json
# /kaggle/input/openqa-questions/openqa_questions/INFOWHYa_W45.json
# /kaggle/input/openqa-questions/openqa_questions/ADMISSIONd_W43.json
# /kaggle/input/openqa-questions/openqa_questions/Q7F2_W42.json
# /kaggle/input/openqa-questions/openqa_questions/RACESURV38_W43.json
# /kaggle/input/openqa-questions/openqa_questions/FUD37C_W34.json
# /kaggle/input/openqa-questions/openqa_questions/INEQ5_e_W54.json
# /kaggle/input/openqa-questions/openqa_questions/TRAITPOLWF1A_W36.json
# /kaggle/input/openqa-questions/openqa_questions/COHABDUR_W50.json
# /kaggle/input/openqa-questions/openqa_questions/CAREGIV7_W27.json
# /kaggle/input/openqa-questions/openqa_questions/VIDOFT_W45.json
# /kaggle/input/openqa-questions/openqa_questions/CANDEXP_W92.json
# /kaggle/input/openqa-questions/openqa_questions/FAMSURV33d_W50.json
# /kaggle/input/openqa-questions/openqa_questions/GAP21Q7_a_W82.json
# /kaggle/input/openqa-questions/openqa_questions/RACESURV41_W43.json
# /kaggle/input/openqa-questions/openqa_questions/FTRWORRYc_W41.json
# /kaggle/input/openqa-questions/openqa_questions/GOVPRIOkF2_W41.json
# /kaggle/input/openqa-questions/openqa_questions/GUNLOADED1_W26.json
# /kaggle/input/openqa-questions/openqa_questions/RTDc_W49.json
# /kaggle/input/openqa-questions/openqa_questions/SCI3C_W34.json
# /kaggle/input/openqa-questions/openqa_questions/PQ5_F2C_W42.json
# /kaggle/input/openqa-questions/openqa_questions/GUNRESPKIDSF_W26.json
# /kaggle/input/openqa-questions/openqa_questions/SATLIFEd_W50.json
# /kaggle/input/openqa-questions/openqa_questions/RACESURV1b_W43.json
# /kaggle/input/openqa-questions/openqa_questions/FAMSURV32c_W50.json
# /kaggle/input/openqa-questions/openqa_questions/RACESURV28f_W43.json
# /kaggle/input/openqa-questions/openqa_questions/GAP21Q43_g_W82.json
# /kaggle/input/openqa-questions/openqa_questions/FCFAIR_W45.json
# /kaggle/input/openqa-questions/openqa_questions/HARASS3F2_W32.json
# /kaggle/input/openqa-questions/openqa_questions/HIRING7B_W27.json
# /kaggle/input/openqa-questions/openqa_questions/WHYNOTPOLF1J_W36.json
# /kaggle/input/openqa-questions/openqa_questions/GROWUPNEAR_W32.json
# /kaggle/input/openqa-questions/openqa_questions/HARASS1F1d_W41.json
# /kaggle/input/openqa-questions/openqa_questions/MARRFAM2_W32.json
# /kaggle/input/openqa-questions/openqa_questions/ROBJOB8G_W27.json
# /kaggle/input/openqa-questions/openqa_questions/TRAITBIZMF2A_W36.json
# /kaggle/input/openqa-questions/openqa_questions/ROBJOB8D_W27.json
# /kaggle/input/openqa-questions/openqa_questions/FAMSURV30e_W50.json
# /kaggle/input/openqa-questions/openqa_questions/WOMENOPPS_W32.json
# /kaggle/input/openqa-questions/openqa_questions/FUTURE_W42.json
# /kaggle/input/openqa-questions/openqa_questions/GUNSOCIETY_W26.json
# /kaggle/input/openqa-questions/openqa_questions/GAP21Q19_d_W82.json
# /kaggle/input/openqa-questions/openqa_questions/RQ3_F1Bd_W42.json
# /kaggle/input/openqa-questions/openqa_questions/FAMSURV2Wa_W50.json
# /kaggle/input/openqa-questions/openqa_questions/PUBLICDATA_W49.json
# /kaggle/input/openqa-questions/openqa_questions/GAP21Q34_a_W82.json
# /kaggle/input/openqa-questions/openqa_questions/FIN_SITFUT_W54.json
# /kaggle/input/openqa-questions/openqa_questions/WHYNOTBIZF2A_W36.json
# /kaggle/input/openqa-questions/openqa_questions/RACESURV45_W43.json
# /kaggle/input/openqa-questions/openqa_questions/TRANSGEND1_W29.json
# /kaggle/input/openqa-questions/openqa_questions/MADEUPIMPc_W45.json
# /kaggle/input/openqa-questions/openqa_questions/LOCALPROBH_W32.json
# /kaggle/input/openqa-questions/openqa_questions/HIGHEDWRNGD_W36.json
# /kaggle/input/openqa-questions/openqa_questions/FIN_SIT_W54.json
# /kaggle/input/openqa-questions/openqa_questions/GOVPROTCT_W92.json
# /kaggle/input/openqa-questions/openqa_questions/POLICY1_W42.json
# /kaggle/input/openqa-questions/openqa_questions/RQ6_F1B_W42.json
# /kaggle/input/openqa-questions/openqa_questions/RACESURV18d_W43.json
# /kaggle/input/openqa-questions/openqa_questions/RQ4_F1Cd_W42.json
# /kaggle/input/openqa-questions/openqa_questions/FAMSURV35a_W50.json
# /kaggle/input/openqa-questions/openqa_questions/SOLVPROBi_W41.json
# /kaggle/input/openqa-questions/openqa_questions/MESUM1_FD_W29.json
# /kaggle/input/openqa-questions/openqa_questions/POLICY2_W42.json
# /kaggle/input/openqa-questions/openqa_questions/S12_W29.json
# /kaggle/input/openqa-questions/openqa_questions/BOYSF1D_W29.json
# /kaggle/input/openqa-questions/openqa_questions/FAMSURV9e_W50.json
# /kaggle/input/openqa-questions/openqa_questions/RQ3_F1Ca_W42.json
# /kaggle/input/openqa-questions/openqa_questions/FUTRCLASSa_W41.json
# /kaggle/input/openqa-questions/openqa_questions/INEQ5_j_W54.json
# /kaggle/input/openqa-questions/openqa_questions/AMNTWMNPF1_W36.json
# /kaggle/input/openqa-questions/openqa_questions/GUNACTIVITYA_W26.json
# /kaggle/input/openqa-questions/openqa_questions/USMILSIZ_W92.json
# /kaggle/input/openqa-questions/openqa_questions/RACESURV10_W43.json
# /kaggle/input/openqa-questions/openqa_questions/MED4A_W34.json
# /kaggle/input/openqa-questions/openqa_questions/GUN1_W26.json
# /kaggle/input/openqa-questions/openqa_questions/FINANCEa_W54.json
# /kaggle/input/openqa-questions/openqa_questions/GOVPRIOmF2_W41.json
# /kaggle/input/openqa-questions/openqa_questions/FUTRCLASSc_W41.json
# /kaggle/input/openqa-questions/openqa_questions/RACESURV37_W43.json
# /kaggle/input/openqa-questions/openqa_questions/HIGHEDWRNGC_W36.json
# /kaggle/input/openqa-questions/openqa_questions/PROBOFF_b_W92.json
# /kaggle/input/openqa-questions/openqa_questions/ROBJOB6_W27.json
# /kaggle/input/openqa-questions/openqa_questions/PREDICTC_W27.json
# /kaggle/input/openqa-questions/openqa_questions/EAT3J_W34.json
# /kaggle/input/openqa-questions/openqa_questions/POLICY3_W42.json
# /kaggle/input/openqa-questions/openqa_questions/INFORESTRICTb_W45.json
# /kaggle/input/openqa-questions/openqa_questions/GAP21Q26_c_W82.json
# /kaggle/input/openqa-questions/openqa_questions/FAMSURV33c_W50.json
# /kaggle/input/openqa-questions/openqa_questions/FAMSURV36a_W50.json
# /kaggle/input/openqa-questions/openqa_questions/ADKIDS_W50.json
# /kaggle/input/openqa-questions/openqa_questions/INSTN_K12_W92.json
# /kaggle/input/openqa-questions/openqa_questions/GAP21Q4_c_W82.json
# /kaggle/input/openqa-questions/openqa_questions/RACESURV50_W43.json
# /kaggle/input/openqa-questions/openqa_questions/TRAITBIZMF2F_W36.json
# /kaggle/input/openqa-questions/openqa_questions/MADEUPRESb_W45.json
# /kaggle/input/openqa-questions/openqa_questions/ROBJOB4F_W27.json
# /kaggle/input/openqa-questions/openqa_questions/INEQ5_b_W54.json
# /kaggle/input/openqa-questions/openqa_questions/ROBJOB5C_W27.json
# /kaggle/input/openqa-questions/openqa_questions/ECIMPi_W54.json
# /kaggle/input/openqa-questions/openqa_questions/SCM5c_W42.json
# /kaggle/input/openqa-questions/openqa_questions/SOCIETY_TRANS_W92.json
# /kaggle/input/openqa-questions/openqa_questions/CARS3A_W27.json
# /kaggle/input/openqa-questions/openqa_questions/SOURCESKEPa_W45.json
# /kaggle/input/openqa-questions/openqa_questions/TRAITBIZWF2D_W36.json
# /kaggle/input/openqa-questions/openqa_questions/NEWSPROBb_W45.json
# /kaggle/input/openqa-questions/openqa_questions/DRONE4D_W27.json
# /kaggle/input/openqa-questions/openqa_questions/RACESURV11_W43.json
# /kaggle/input/openqa-questions/openqa_questions/INEQ5_k_W54.json
# /kaggle/input/openqa-questions/openqa_questions/MARRYPREF2_W50.json
# /kaggle/input/openqa-questions/openqa_questions/GOVREGV1_W49.json
# /kaggle/input/openqa-questions/openqa_questions/RQ4_F1Bd_W42.json
# /kaggle/input/openqa-questions/openqa_questions/INSTN_CHR_W92.json
# /kaggle/input/openqa-questions/openqa_questions/ROBIMPACTa_W41.json
# /kaggle/input/openqa-questions/openqa_questions/RQ5_F1A_W42.json
# /kaggle/input/openqa-questions/openqa_questions/GAP21Q34_c_W82.json
# /kaggle/input/openqa-questions/openqa_questions/MOREWMN4F2_W36.json
# /kaggle/input/openqa-questions/openqa_questions/BETTERPOL1F1C_W36.json
# /kaggle/input/openqa-questions/openqa_questions/ECONFAIR_W92.json
# /kaggle/input/openqa-questions/openqa_questions/RQ2_F1A_W42.json
# /kaggle/input/openqa-questions/openqa_questions/WATCHDOG_1_W45.json
# /kaggle/input/openqa-questions/openqa_questions/PROFILE5_W49.json
# /kaggle/input/openqa-questions/openqa_questions/FAMSURV26c_W50.json
# /kaggle/input/openqa-questions/openqa_questions/ECIMPf_W54.json
# /kaggle/input/openqa-questions/openqa_questions/PROBURBAN_W32.json
# /kaggle/input/openqa-questions/openqa_questions/SOCIETY_SSM_W92.json
# /kaggle/input/openqa-questions/openqa_questions/SOCTRUST2_W32.json
# /kaggle/input/openqa-questions/openqa_questions/WHYNOTBIZF2H_W36.json
# /kaggle/input/openqa-questions/openqa_questions/DNA4_W50.json
# /kaggle/input/openqa-questions/openqa_questions/GUNACTIVITYD_W26.json
# /kaggle/input/openqa-questions/openqa_questions/SATLIFEE_W32.json
# /kaggle/input/openqa-questions/openqa_questions/PQ3_F2Bc_W42.json
# /kaggle/input/openqa-questions/openqa_questions/TRAITBIZWF2C_W36.json
# /kaggle/input/openqa-questions/openqa_questions/GOVPRIOlF2_W41.json
# /kaggle/input/openqa-questions/openqa_questions/ECON1_W54.json
# /kaggle/input/openqa-questions/openqa_questions/AMNTWMNB2F1_W36.json
# /kaggle/input/openqa-questions/openqa_questions/GAP21Q15_b_W82.json
# /kaggle/input/openqa-questions/openqa_questions/BETTERBIZ1F2H_W36.json
# /kaggle/input/openqa-questions/openqa_questions/FAMSURV22e_W50.json
# /kaggle/input/openqa-questions/openqa_questions/ECON3_f_W54.json
# /kaggle/input/openqa-questions/openqa_questions/SNSUSE_W45.json
# /kaggle/input/openqa-questions/openqa_questions/GOVPRIOa_W41.json
# /kaggle/input/openqa-questions/openqa_questions/VTRGHTPRIV1_W92.json
# /kaggle/input/openqa-questions/openqa_questions/ADMISSIONg_W43.json
# /kaggle/input/openqa-questions/openqa_questions/SOURCESKEPe_W45.json
# /kaggle/input/openqa-questions/openqa_questions/SUCCESSIMPD_W32.json
# /kaggle/input/openqa-questions/openqa_questions/ROBJOB8A_W27.json
# /kaggle/input/openqa-questions/openqa_questions/BETTERBIZ2F2B_W36.json
# /kaggle/input/openqa-questions/openqa_questions/RQ8_F1A_W42.json
# /kaggle/input/openqa-questions/openqa_questions/FAMSURV18A_W50.json
# /kaggle/input/openqa-questions/openqa_questions/CARS7A_W27.json
# /kaggle/input/openqa-questions/openqa_questions/RQ7_F1C_W42.json
# /kaggle/input/openqa-questions/openqa_questions/TRAITBIZMF2G_W36.json
# /kaggle/input/openqa-questions/openqa_questions/WHYNOTBIZF2B_W36.json
# /kaggle/input/openqa-questions/openqa_questions/GAP21Q3_W82.json
# /kaggle/input/openqa-questions/openqa_questions/FTRWORRYe_W41.json
# /kaggle/input/openqa-questions/openqa_questions/SUCCESSIMPB_W32.json
# /kaggle/input/openqa-questions/openqa_questions/PQ4_F2Bc_W42.json
# /kaggle/input/openqa-questions/openqa_questions/GAP21Q35_W82.json
# /kaggle/input/openqa-questions/openqa_questions/FAMSURV22g_W50.json
# /kaggle/input/openqa-questions/openqa_questions/RACESURV34b_W43.json
# /kaggle/input/openqa-questions/openqa_questions/PQ2_F2C_W42.json
# /kaggle/input/openqa-questions/openqa_questions/PQ6_F2A_W42.json
# /kaggle/input/openqa-questions/openqa_questions/PQ2_F2A_W42.json
# /kaggle/input/openqa-questions/openqa_questions/MESUM1_FE_W29.json
# /kaggle/input/openqa-questions/openqa_questions/TRAITBIZMF2B_W36.json
# /kaggle/input/openqa-questions/openqa_questions/ROBJOB8B_W27.json
# /kaggle/input/openqa-questions/openqa_questions/MADEUPRESa_W45.json
# /kaggle/input/openqa-questions/openqa_questions/GUNSAFETYKIDS_W26.json
# /kaggle/input/openqa-questions/openqa_questions/WORRYRET_W29.json
# /kaggle/input/openqa-questions/openqa_questions/GAP21Q23_W82.json
# /kaggle/input/openqa-questions/openqa_questions/SMLIKESe_W45.json
# /kaggle/input/openqa-questions/openqa_questions/WHYNOTPOLF1H_W36.json
# /kaggle/input/openqa-questions/openqa_questions/BENEFITSc_W54.json
# /kaggle/input/openqa-questions/openqa_questions/DEBTe_W54.json
# /kaggle/input/openqa-questions/openqa_questions/DRONE4A_W27.json
# /kaggle/input/openqa-questions/openqa_questions/RQ2_F1B_W42.json
# /kaggle/input/openqa-questions/openqa_questions/RACESURV53c_W43.json
# /kaggle/input/openqa-questions/openqa_questions/INFORESTRICTa_W45.json
# /kaggle/input/openqa-questions/openqa_questions/RACESURV1a_W43.json
# /kaggle/input/openqa-questions/openqa_questions/DRONE4C_W27.json
# /kaggle/input/openqa-questions/openqa_questions/INSTN_MSCENT_W92.json
# /kaggle/input/openqa-questions/openqa_questions/BETTERPOL1F1E_W36.json
# /kaggle/input/openqa-questions/openqa_questions/INEQ4_e_W54.json
# /kaggle/input/openqa-questions/openqa_questions/PAR2CHILDa_W92.json
# /kaggle/input/openqa-questions/openqa_questions/RACESURV28g_W43.json
# /kaggle/input/openqa-questions/openqa_questions/WHYNOTBIZF2D_W36.json
# /kaggle/input/openqa-questions/openqa_questions/PP5a_W49.json
# /kaggle/input/openqa-questions/openqa_questions/SCM5a_W42.json
# /kaggle/input/openqa-questions/openqa_questions/ELDFINANCEF1_W41.json
# /kaggle/input/openqa-questions/openqa_questions/SOURCESKEPd_W45.json
# /kaggle/input/openqa-questions/openqa_questions/GUNKILLF1_W26.json
# /kaggle/input/openqa-questions/openqa_questions/BETTERPOL1F1F_W36.json
# /kaggle/input/openqa-questions/openqa_questions/MED4C_W34.json
# /kaggle/input/openqa-questions/openqa_questions/SCM5h_W42.json
# /kaggle/input/openqa-questions/openqa_questions/MED2A_W34.json
# /kaggle/input/openqa-questions/openqa_questions/SCI2B_W34.json
# /kaggle/input/openqa-questions/openqa_questions/MADEUPIMPb_W45.json
# /kaggle/input/openqa-questions/openqa_questions/FAMSURV27d_W50.json
# /kaggle/input/openqa-questions/openqa_questions/IMPROVE1_W36.json
# /kaggle/input/openqa-questions/openqa_questions/TRAITSA_W29.json
# /kaggle/input/openqa-questions/openqa_questions/FAMSURV11M_W50.json
# /kaggle/input/openqa-questions/openqa_questions/BOYSF1C_W29.json
# /kaggle/input/openqa-questions/openqa_questions/MESUM2_FE_W29.json
# /kaggle/input/openqa-questions/openqa_questions/BETTERBIZ1F2E_W36.json
# /kaggle/input/openqa-questions/openqa_questions/INFOCHALc_W45.json
# /kaggle/input/openqa-questions/openqa_questions/RQ1_F1B_W42.json
# /kaggle/input/openqa-questions/openqa_questions/WHYNOTBIZF2F_W36.json
# /kaggle/input/openqa-questions/openqa_questions/PQ4_F2Ac_W42.json
# /kaggle/input/openqa-questions/openqa_questions/HARASS3NOWRKF2_W41.json
# /kaggle/input/openqa-questions/openqa_questions/PROBOFF_a_W92.json
# /kaggle/input/openqa-questions/openqa_questions/RQ4_F1Cc_W42.json
# /kaggle/input/openqa-questions/openqa_questions/HIGHEDWRNGA_W36.json
# /kaggle/input/openqa-questions/openqa_questions/ADMISSIONe_W43.json
# /kaggle/input/openqa-questions/openqa_questions/INEQ8_i_W54.json
# /kaggle/input/openqa-questions/openqa_questions/TRAITSB_W29.json
# /kaggle/input/openqa-questions/openqa_questions/WORRYE_W26.json
# /kaggle/input/openqa-questions/openqa_questions/DB1a_W49.json
# /kaggle/input/openqa-questions/openqa_questions/HIGHED_W36.json
# /kaggle/input/openqa-questions/openqa_questions/ALLIES_W92.json
# /kaggle/input/openqa-questions/openqa_questions/FEM2BF2_W29.json
# /kaggle/input/openqa-questions/openqa_questions/COMMIMPF_W32.json
# /kaggle/input/openqa-questions/openqa_questions/HOOD_NHISA_W29.json
# /kaggle/input/openqa-questions/openqa_questions/GAP21Q43_a_W82.json
# /kaggle/input/openqa-questions/openqa_questions/BETTERBIZ1F2C_W36.json
# /kaggle/input/openqa-questions/openqa_questions/COMMIMPE_W32.json
# /kaggle/input/openqa-questions/openqa_questions/HARASS1B_W32.json
# /kaggle/input/openqa-questions/openqa_questions/WORK3B_W27.json
# /kaggle/input/openqa-questions/openqa_questions/BETTERPOL2F1C_W36.json
# /kaggle/input/openqa-questions/openqa_questions/GAP21Q14_W82.json
# /kaggle/input/openqa-questions/openqa_questions/WHYNOTBIZF2I_W36.json
# /kaggle/input/openqa-questions/openqa_questions/CRIM_SENT2_W92.json
# /kaggle/input/openqa-questions/openqa_questions/SOLVPROBb_W41.json
# /kaggle/input/openqa-questions/openqa_questions/INFOOWNc_W45.json
# /kaggle/input/openqa-questions/openqa_questions/BETTERBIZ1F2I_W36.json
# /kaggle/input/openqa-questions/openqa_questions/HIRING6A_W27.json
# /kaggle/input/openqa-questions/openqa_questions/FAMSURV5c_W50.json
# /kaggle/input/openqa-questions/openqa_questions/INTRMAR_W41.json
# /kaggle/input/openqa-questions/openqa_questions/FAMSURV28_W50.json
# /kaggle/input/openqa-questions/openqa_questions/FACE4a_W49.json
# /kaggle/input/openqa-questions/openqa_questions/MADEUPIMPe_W45.json
# /kaggle/input/openqa-questions/openqa_questions/MED6E_W34.json
# /kaggle/input/openqa-questions/openqa_questions/GOVSIZE1_W92.json
# /kaggle/input/openqa-questions/openqa_questions/AGEMAJ_W41.json
# /kaggle/input/openqa-questions/openqa_questions/ESSENPOLF1E_W36.json
# /kaggle/input/openqa-questions/openqa_questions/GAP21Q19_c_W82.json
# /kaggle/input/openqa-questions/openqa_questions/LOCALELECT_W29.json
# /kaggle/input/openqa-questions/openqa_questions/HAPPENj_W41.json
# /kaggle/input/openqa-questions/openqa_questions/CONFa_W42.json
# /kaggle/input/openqa-questions/openqa_questions/ELECTFTGSNSINT_W49.json
# /kaggle/input/openqa-questions/openqa_questions/EAT2_W34.json
# /kaggle/input/openqa-questions/openqa_questions/TALK_CPS_W29.json
# /kaggle/input/openqa-questions/openqa_questions/INFOCREATEc_W45.json
# /kaggle/input/openqa-questions/openqa_questions/INEQ5_h_W54.json
# /kaggle/input/openqa-questions/openqa_questions/FTRWORRYf_W41.json
# /kaggle/input/openqa-questions/openqa_questions/FACE1_W49.json
# /kaggle/input/openqa-questions/openqa_questions/SCM5g_W42.json
# /kaggle/input/openqa-questions/openqa_questions/DB1c_W49.json
# /kaggle/input/openqa-questions/openqa_questions/FAMSURV30b_W50.json
# /kaggle/input/openqa-questions/openqa_questions/FAMNEAR_W32.json
# /kaggle/input/openqa-questions/openqa_questions/WORRY2d_W54.json
# /kaggle/input/openqa-questions/openqa_questions/PQ3_F2Ba_W42.json
# /kaggle/input/openqa-questions/openqa_questions/HAPPENg_W41.json
# /kaggle/input/openqa-questions/openqa_questions/INEQ8_a_W54.json
# /kaggle/input/openqa-questions/openqa_questions/RACESURV2_W43.json
# /kaggle/input/openqa-questions/openqa_questions/EARN_W36.json
# /kaggle/input/openqa-questions/openqa_questions/FAMSURV38b_W50.json
# /kaggle/input/openqa-questions/openqa_questions/SHARE1_W49.json
# /kaggle/input/openqa-questions/openqa_questions/RACESURV5c_W43.json
# /kaggle/input/openqa-questions/openqa_questions/POP3_W42.json
# /kaggle/input/openqa-questions/openqa_questions/NOGOVTHC_W92.json
# /kaggle/input/openqa-questions/openqa_questions/GAP21Q34_f_W82.json
# /kaggle/input/openqa-questions/openqa_questions/EVOTHREE_W34.json
# /kaggle/input/openqa-questions/openqa_questions/NEIGHKEYS_W32.json
# /kaggle/input/openqa-questions/openqa_questions/RQ3_F1Ad_W42.json
# /kaggle/input/openqa-questions/openqa_questions/BETTERPOL1F1H_W36.json
# /kaggle/input/openqa-questions/openqa_questions/FAMSURV2We_W50.json
# /kaggle/input/openqa-questions/openqa_questions/RQ1_F1C_W42.json
# /kaggle/input/openqa-questions/openqa_questions/GUNASSOCIATIONA_W26.json
# /kaggle/input/openqa-questions/openqa_questions/NEIGHINTERC_W32.json
# /kaggle/input/openqa-questions/openqa_questions/RACESURV29c_W43.json
# /kaggle/input/openqa-questions/openqa_questions/GROWUPGUN2C_W26.json
# /kaggle/input/openqa-questions/openqa_questions/RQ7_F1B_W42.json
# /kaggle/input/openqa-questions/openqa_questions/FAMSURV22f_W50.json
# /kaggle/input/openqa-questions/openqa_questions/PQ6_F2C_W42.json
# /kaggle/input/openqa-questions/openqa_questions/BETTERBIZ1F2F_W36.json
# /kaggle/input/openqa-questions/openqa_questions/SOCTRUST5_W32.json
# /kaggle/input/openqa-questions/openqa_questions/HAPPENe_W41.json
# /kaggle/input/openqa-questions/openqa_questions/HAPPEN2g_W41.json
# /kaggle/input/openqa-questions/openqa_questions/CRIMEVICTIM_W26.json
# /kaggle/input/openqa-questions/openqa_questions/ADMISSIONa_W43.json
# /kaggle/input/openqa-questions/openqa_questions/SUBURBNEAR_W32.json
# /kaggle/input/openqa-questions/openqa_questions/GOVPRIOd_W41.json
# /kaggle/input/openqa-questions/openqa_questions/DIFF1A_W29.json
# /kaggle/input/openqa-questions/openqa_questions/ECON1B_W54.json
# /kaggle/input/openqa-questions/openqa_questions/FAMSURV26b_W50.json
# /kaggle/input/openqa-questions/openqa_questions/GAP21Q33_p_W82.json
# /kaggle/input/openqa-questions/openqa_questions/CARS10A_W27.json
# /kaggle/input/openqa-questions/openqa_questions/PQ7_F2B_W42.json
# /kaggle/input/openqa-questions/openqa_questions/GAP21Q19_b_W82.json
# /kaggle/input/openqa-questions/openqa_questions/GAP21Q38_a_W82.json
# /kaggle/input/openqa-questions/openqa_questions/WHYNOTPOLF1E_W36.json
# /kaggle/input/openqa-questions/openqa_questions/USEXCEPT_W92.json
# /kaggle/input/openqa-questions/openqa_questions/TRAITPOLWF1F_W36.json
# /kaggle/input/openqa-questions/openqa_questions/GUNRESPNOKIDSF_W26.json
# /kaggle/input/openqa-questions/openqa_questions/SUCCESSIMPC_W32.json
# /kaggle/input/openqa-questions/openqa_questions/ORIENTATIONMOD_W50.json
# /kaggle/input/openqa-questions/openqa_questions/SOCIETY_JBCLL_W92.json
# /kaggle/input/openqa-questions/openqa_questions/EQUALPOLF2_W36.json
# /kaggle/input/openqa-questions/openqa_questions/TRACKGOV1a_W49.json
# /kaggle/input/openqa-questions/openqa_questions/WORK3A_W27.json
# /kaggle/input/openqa-questions/openqa_questions/INSTN_BNKS_W92.json
# /kaggle/input/openqa-questions/openqa_questions/CONCERNGOV_W49.json
# /kaggle/input/openqa-questions/openqa_questions/FACE4b_W49.json
# /kaggle/input/openqa-questions/openqa_questions/RACESURV5b_W43.json
# /kaggle/input/openqa-questions/openqa_questions/GAP21Q18_W82.json
# /kaggle/input/openqa-questions/openqa_questions/GUNSAFE2_W26.json
# /kaggle/input/openqa-questions/openqa_questions/ROBWRK2_W41.json
# /kaggle/input/openqa-questions/openqa_questions/SEEK_W45.json
# /kaggle/input/openqa-questions/openqa_questions/FIN_SITGROWUP_W54.json
# /kaggle/input/openqa-questions/openqa_questions/POP1_W42.json
# /kaggle/input/openqa-questions/openqa_questions/HIRING2_W27.json
# /kaggle/input/openqa-questions/openqa_questions/DIFFPARTY_W92.json
# /kaggle/input/openqa-questions/openqa_questions/VOICE1_W27.json
# /kaggle/input/openqa-questions/openqa_questions/MOVEURBAN_W32.json
# /kaggle/input/openqa-questions/openqa_questions/PRIVACYNEWS1_W49.json
# /kaggle/input/openqa-questions/openqa_questions/GOVPRIORITYd_W54.json
# /kaggle/input/openqa-questions/openqa_questions/POORASSIST_W92.json
# /kaggle/input/openqa-questions/openqa_questions/FAMSURV10b_W50.json
# /kaggle/input/openqa-questions/openqa_questions/PAR2CHILD_W92.json
# /kaggle/input/openqa-questions/openqa_questions/REMARR_W50.json
# /kaggle/input/openqa-questions/openqa_questions/TRAITPOLMF1E_W36.json
# /kaggle/input/openqa-questions/openqa_questions/GAP21Q32_W82.json
# /kaggle/input/openqa-questions/openqa_questions/LOCALPROBF_W32.json
# /kaggle/input/openqa-questions/openqa_questions/RQ4_F1Ab_W42.json
# /kaggle/input/openqa-questions/openqa_questions/GAP21Q11_W82.json
# /kaggle/input/openqa-questions/openqa_questions/REASONGUNC_W26.json
# /kaggle/input/openqa-questions/openqa_questions/SATLIFED_W32.json
# /kaggle/input/openqa-questions/openqa_questions/RACESURV5e_W43.json
# /kaggle/input/openqa-questions/openqa_questions/FAMSURV32d_W50.json
# /kaggle/input/openqa-questions/openqa_questions/ESSENBIZF2G_W36.json
# /kaggle/input/openqa-questions/openqa_questions/GAP21Q25_W82.json
# /kaggle/input/openqa-questions/openqa_questions/GROWUPGUN6_W26.json
# /kaggle/input/openqa-questions/openqa_questions/GOVTHC_W92.json
# /kaggle/input/openqa-questions/openqa_questions/WHYNOTBIZF2O_W36.json
# /kaggle/input/openqa-questions/openqa_questions/GOVSIZE2_W92.json
# /kaggle/input/openqa-questions/openqa_questions/ADMISSIONh_W43.json
# /kaggle/input/openqa-questions/openqa_questions/RQ4_F1Ae_W42.json
# /kaggle/input/openqa-questions/openqa_questions/GOVRESP_c_W54.json
# /kaggle/input/openqa-questions/openqa_questions/INEQ9_W54.json
# /kaggle/input/openqa-questions/openqa_questions/FUD33B_W34.json
# /kaggle/input/openqa-questions/openqa_questions/GAP21Q4_a_W82.json
# /kaggle/input/openqa-questions/openqa_questions/INFOCHALb_W45.json
# /kaggle/input/openqa-questions/openqa_questions/FEM2AF2_W29.json
# /kaggle/input/openqa-questions/openqa_questions/EVOTWO_W34.json
# /kaggle/input/openqa-questions/openqa_questions/FAMSURV11W_W50.json
# /kaggle/input/openqa-questions/openqa_questions/FAMSURV32b_W50.json
# /kaggle/input/openqa-questions/openqa_questions/WHYNOTBIZF2C_W36.json
# /kaggle/input/openqa-questions/openqa_questions/RACESURV5i_W43.json
# /kaggle/input/openqa-questions/openqa_questions/GAP21Q26_d_W82.json
# /kaggle/input/openqa-questions/openqa_questions/RACESURV53a_W43.json
# /kaggle/input/openqa-questions/openqa_questions/EAT3I_W34.json
# /kaggle/input/openqa-questions/openqa_questions/HOMEASSIST1_W49.json
# /kaggle/input/openqa-questions/openqa_questions/HIRING6B_W27.json
# /kaggle/input/openqa-questions/openqa_questions/PREDICTA_W27.json
# /kaggle/input/openqa-questions/openqa_questions/MADEUPTOPICd_W45.json
# /kaggle/input/openqa-questions/openqa_questions/RQ3_F1Bb_W42.json
# /kaggle/input/openqa-questions/openqa_questions/GAP21Q34_b_W82.json
# /kaggle/input/openqa-questions/openqa_questions/GAP21Q21_b_W82.json
# /kaggle/input/openqa-questions/openqa_questions/RACESURV4_W43.json
# /kaggle/input/openqa-questions/openqa_questions/GAP21Q33_t_W82.json
# /kaggle/input/openqa-questions/openqa_questions/NEIGHKIDS_W32.json
# /kaggle/input/openqa-questions/openqa_questions/LOCALPROBC_W32.json
# /kaggle/input/openqa-questions/openqa_questions/GAP21Q38_b_W82.json
# /kaggle/input/openqa-questions/openqa_questions/WORK6_W27.json
# /kaggle/input/openqa-questions/openqa_questions/PQ3_F2Ab_W42.json
# /kaggle/input/openqa-questions/openqa_questions/RQ8_F1C_W42.json
# /kaggle/input/openqa-questions/openqa_questions/POP2_W42.json
# /kaggle/input/openqa-questions/openqa_questions/CAREGIV6F_W27.json
# /kaggle/input/openqa-questions/openqa_questions/SOCIETY_RHIST_W92.json
# /kaggle/input/openqa-questions/openqa_questions/RACESURV53b_W43.json
# /kaggle/input/openqa-questions/openqa_questions/RACESURV19b_W43.json
# /kaggle/input/openqa-questions/openqa_questions/GAP21Q46_W82.json
# /kaggle/input/openqa-questions/openqa_questions/MADEUPTOPICf_W45.json
# /kaggle/input/openqa-questions/openqa_questions/SCI2C_W34.json
# /kaggle/input/openqa-questions/openqa_questions/CARS4_W27.json
# /kaggle/input/openqa-questions/openqa_questions/RACESURV34a_W43.json
# /kaggle/input/openqa-questions/openqa_questions/GAP21Q27_W82.json
# /kaggle/input/openqa-questions/openqa_questions/GUNCONTRIBF_W26.json
# /kaggle/input/openqa-questions/openqa_questions/MASC2AF1_W29.json
# /kaggle/input/openqa-questions/openqa_questions/GIRLSF2C_W29.json
# /kaggle/input/openqa-questions/openqa_questions/CARS10B_W27.json
# /kaggle/input/openqa-questions/openqa_questions/GAP21Q33_h_W82.json
# /kaggle/input/openqa-questions/openqa_questions/INFOCHALd_W45.json
# /kaggle/input/openqa-questions/openqa_questions/FUD22_W34.json
# /kaggle/input/openqa-questions/openqa_questions/RQ3_F1Ac_W42.json
# /kaggle/input/openqa-questions/openqa_questions/HIRING6C_W27.json
# /kaggle/input/openqa-questions/openqa_questions/INFOCHALe_W45.json
# /kaggle/input/openqa-questions/openqa_questions/GAP21Q8_W82.json
# /kaggle/input/openqa-questions/openqa_questions/FUTR_M_W41.json
# /kaggle/input/openqa-questions/openqa_questions/INSTN_TECHCMP_W92.json
# /kaggle/input/openqa-questions/openqa_questions/IMPROVE2_W36.json
# /kaggle/input/openqa-questions/openqa_questions/MADEUPTOPICe_W45.json
# /kaggle/input/openqa-questions/openqa_questions/TRAITPOLMF1A_W36.json
# /kaggle/input/openqa-questions/openqa_questions/ECON5_b_W54.json
# /kaggle/input/openqa-questions/openqa_questions/MED6C_W34.json
# /kaggle/input/openqa-questions/openqa_questions/BETTERBIZ2F2E_W36.json
# /kaggle/input/openqa-questions/openqa_questions/ECON3_e_W54.json
# /kaggle/input/openqa-questions/openqa_questions/RESTRICTWHO_W45.json
# /kaggle/input/openqa-questions/openqa_questions/INEQ6_W54.json
# /kaggle/input/openqa-questions/openqa_questions/ESSENBIZF2K_W36.json
# /kaggle/input/openqa-questions/openqa_questions/ESSENBIZF2A_W36.json
# /kaggle/input/openqa-questions/openqa_questions/ECIMPj_W54.json
# /kaggle/input/openqa-questions/openqa_questions/MED5_W34.json
# /kaggle/input/openqa-questions/openqa_questions/INFOKNOWd_W45.json
# /kaggle/input/openqa-questions/openqa_questions/RACESURV19d_W43.json
# /kaggle/input/openqa-questions/openqa_questions/GOVWASTE_W92.json
# /kaggle/input/openqa-questions/openqa_questions/LWPT_W50.json
# /kaggle/input/openqa-questions/openqa_questions/RQ4_F1Bc_W42.json
# /kaggle/input/openqa-questions/openqa_questions/FAMSURV7_W50.json
# /kaggle/input/openqa-questions/openqa_questions/WHYNOTBIZF2N_W36.json
# /kaggle/input/openqa-questions/openqa_questions/DEBTc_W54.json
# /kaggle/input/openqa-questions/openqa_questions/SCI5_W34.json
# /kaggle/input/openqa-questions/openqa_questions/ADMISSIONc_W43.json
# /kaggle/input/openqa-questions/openqa_questions/RACESURV5k_W43.json
# /kaggle/input/openqa-questions/openqa_questions/GAP21Q33_b_W82.json
# /kaggle/input/openqa-questions/openqa_questions/TALKCMNSNSINT_W49.json
# /kaggle/input/openqa-questions/openqa_questions/RACESURV13_W43.json
# /kaggle/input/openqa-questions/openqa_questions/RACESURV24_W43.json
# /kaggle/input/openqa-questions/openqa_questions/INEQ5_d_W54.json
# /kaggle/input/openqa-questions/openqa_questions/BETTERBIZ1F2A_W36.json
# /kaggle/input/openqa-questions/openqa_questions/CARS5_W27.json
# /kaggle/input/openqa-questions/openqa_questions/MASC2BF1_W29.json
# /kaggle/input/openqa-questions/openqa_questions/INFOCREATEe_W45.json
# /kaggle/input/openqa-questions/openqa_questions/INFOCONFUSEd_W45.json
# /kaggle/input/openqa-questions/openqa_questions/GOVT_ROLE_W32.json
# /kaggle/input/openqa-questions/openqa_questions/PROBSUBURB_W32.json
# /kaggle/input/openqa-questions/openqa_questions/VALUESUBURB_W32.json
# /kaggle/input/openqa-questions/openqa_questions/MADEUPSHARE2_W45.json
# /kaggle/input/openqa-questions/openqa_questions/MAN1D_W29.json
# /kaggle/input/openqa-questions/openqa_questions/GOVRESP_b_W54.json
# /kaggle/input/openqa-questions/openqa_questions/SCM5j_W42.json
# /kaggle/input/openqa-questions/openqa_questions/ESSENPOLF1H_W36.json
# /kaggle/input/openqa-questions/openqa_questions/HOOD_NHISB_W29.json
# /kaggle/input/openqa-questions/openqa_questions/INEQ10_W54.json
# /kaggle/input/openqa-questions/openqa_questions/RQ4_F1Ba_W42.json
# /kaggle/input/openqa-questions/openqa_questions/DNA2a_W50.json
# /kaggle/input/openqa-questions/openqa_questions/GOVPRIORITYb_W54.json
# /kaggle/input/openqa-questions/openqa_questions/PP5b_W49.json
# /kaggle/input/openqa-questions/openqa_questions/NEWSPROBd_W45.json
# /kaggle/input/openqa-questions/openqa_questions/RQ4_F1Bb_W42.json
# /kaggle/input/openqa-questions/openqa_questions/INFOCONFUSEa_W45.json
# /kaggle/input/openqa-questions/openqa_questions/SSCUT_W41.json
# /kaggle/input/openqa-questions/openqa_questions/GAP21Q15_a_W82.json
# /kaggle/input/openqa-questions/openqa_questions/HELPHURTF_W29.json
# /kaggle/input/openqa-questions/openqa_questions/GUNRESPKIDSB_W26.json
# /kaggle/input/openqa-questions/openqa_questions/GUNRESPNOKIDSB_W26.json
# /kaggle/input/openqa-questions/openqa_questions/MADEUPSOLVE_W45.json
# /kaggle/input/openqa-questions/openqa_questions/DEBTb_W54.json
# /kaggle/input/openqa-questions/openqa_questions/SOURCESKEPc_W45.json
# /kaggle/input/openqa-questions/openqa_questions/MASC2_W29.json
# /kaggle/input/openqa-questions/openqa_questions/ECON5_h_W54.json
# /kaggle/input/openqa-questions/openqa_questions/PQ3_F2Ac_W42.json
# /kaggle/input/openqa-questions/openqa_questions/INFOKNOWa_W45.json
# /kaggle/input/openqa-questions/openqa_questions/HAPPEN2d_W41.json
# /kaggle/input/openqa-questions/openqa_questions/INFOCREATEb_W45.json
# /kaggle/input/openqa-questions/openqa_questions/RACESURV47c_W43.json
# /kaggle/input/openqa-questions/openqa_questions/RACESURV21_W43.json
# /kaggle/input/openqa-questions/openqa_questions/MADEUPSMCLICK_W45.json
# /kaggle/input/openqa-questions/openqa_questions/CONFf_W42.json
# /kaggle/input/openqa-questions/openqa_questions/GAP21Q21_a_W82.json
# /kaggle/input/openqa-questions/openqa_questions/INEQ4_c_W54.json
# /kaggle/input/openqa-questions/openqa_questions/WORK4B_W27.json
# /kaggle/input/openqa-questions/openqa_questions/STYLE1_W36.json
# /kaggle/input/openqa-questions/openqa_questions/GOVRESP_g_W54.json
# /kaggle/input/openqa-questions/openqa_questions/GOVPRIOgF1_W41.json
# /kaggle/input/openqa-questions/openqa_questions/RACESURV49_W43.json
# /kaggle/input/openqa-questions/openqa_questions/BETTERPOL1F1A_W36.json
# /kaggle/input/openqa-questions/openqa_questions/MESUM1_FC_W29.json
# /kaggle/input/openqa-questions/openqa_questions/ECON3_g_W54.json
# /kaggle/input/openqa-questions/openqa_questions/GAP21Q43_d_W82.json
# /kaggle/input/openqa-questions/openqa_questions/DNA3c_W50.json
# /kaggle/input/openqa-questions/openqa_questions/INFOOWNe_W45.json
# /kaggle/input/openqa-questions/openqa_questions/DIFF1C_W29.json
# /kaggle/input/openqa-questions/openqa_questions/HIGHEDWRNGB_W36.json
# /kaggle/input/openqa-questions/openqa_questions/MARRFAM_W92.json
# /kaggle/input/openqa-questions/openqa_questions/GIRLSF2D_W29.json
# /kaggle/input/openqa-questions/openqa_questions/ONLINESOURCE_W45.json
# /kaggle/input/openqa-questions/openqa_questions/WORRY2b_W54.json
# /kaggle/input/openqa-questions/openqa_questions/POSNEGGOV_W49.json
# /kaggle/input/openqa-questions/openqa_questions/RACESURV25_W43.json
# /kaggle/input/openqa-questions/openqa_questions/RACESURV15b_W43.json
# /kaggle/input/openqa-questions/openqa_questions/PP3_W49.json
# /kaggle/input/openqa-questions/openqa_questions/NEIGHSAMEC_W32.json
# /kaggle/input/openqa-questions/openqa_questions/TRAITBIZMF2E_W36.json
# /kaggle/input/openqa-questions/openqa_questions/FUTRCLASSb_W41.json
# /kaggle/input/openqa-questions/openqa_questions/JOBSECURITY_W41.json
# /kaggle/input/openqa-questions/openqa_questions/COMATTACH_W32.json
# /kaggle/input/openqa-questions/openqa_questions/RTDb_W49.json
# /kaggle/input/openqa-questions/openqa_questions/GAP21Q5_a_W82.json
# /kaggle/input/openqa-questions/openqa_questions/ROBJOB4D_W27.json
# /kaggle/input/openqa-questions/openqa_questions/FAMSURV22c_W50.json
# /kaggle/input/openqa-questions/openqa_questions/DATAUSEc_W49.json
# /kaggle/input/openqa-questions/openqa_questions/PQ4_F2Ae_W42.json
# /kaggle/input/openqa-questions/openqa_questions/CONCERNGRPf_W49.json
# /kaggle/input/openqa-questions/openqa_questions/WORRYF_W26.json
# /kaggle/input/openqa-questions/openqa_questions/PQ1_F2B_W42.json
# /kaggle/input/openqa-questions/openqa_questions/GROWUPVIOL_W26.json
# /kaggle/input/openqa-questions/openqa_questions/ECON3_i_W54.json
# /kaggle/input/openqa-questions/openqa_questions/ECON3_a_W54.json
# /kaggle/input/openqa-questions/openqa_questions/DEFENDGUN_W26.json
# /kaggle/input/openqa-questions/openqa_questions/SNGLPYER_W92.json
# /kaggle/input/openqa-questions/openqa_questions/GAP21Q33_l_W82.json
# /kaggle/input/openqa-questions/openqa_questions/GAP21Q6_W82.json
# /kaggle/input/openqa-questions/openqa_questions/PQ3_F2Cc_W42.json
# /kaggle/input/openqa-questions/openqa_questions/FAMSURV17_W50.json
# /kaggle/input/openqa-questions/openqa_questions/TRAITPOLWF1C_W36.json
# /kaggle/input/openqa-questions/openqa_questions/INEQ11_W54.json
# /kaggle/input/openqa-questions/openqa_questions/ROBWRK_W41.json
# /kaggle/input/openqa-questions/openqa_questions/COMMIMPA_W32.json
# /kaggle/input/openqa-questions/openqa_questions/RACESURV28b_W43.json
# /kaggle/input/openqa-questions/openqa_questions/TRAITPOLMF1B_W36.json
# /kaggle/input/openqa-questions/openqa_questions/PARTICIPATEB_W29.json
# /kaggle/input/openqa-questions/openqa_questions/GAP21Q22_W82.json
# /kaggle/input/openqa-questions/openqa_questions/RACESURV15a_W43.json
# /kaggle/input/openqa-questions/openqa_questions/WORRYB_W26.json
# /kaggle/input/openqa-questions/openqa_questions/IDIMPORT_W43.json
# /kaggle/input/openqa-questions/openqa_questions/HELPHURTE_W29.json
# /kaggle/input/openqa-questions/openqa_questions/PQ2_F2B_W42.json
# /kaggle/input/openqa-questions/openqa_questions/CONFb_W42.json
# /kaggle/input/openqa-questions/openqa_questions/RACESURV19f_W43.json
# /kaggle/input/openqa-questions/openqa_questions/MADEUPTOPICb_W45.json
# /kaggle/input/openqa-questions/openqa_questions/SATLIFEB_W32.json
# /kaggle/input/openqa-questions/openqa_questions/ROBJOB5B_W27.json
# /kaggle/input/openqa-questions/openqa_questions/PROBRURAL_W32.json
# /kaggle/input/openqa-questions/openqa_questions/FREECOLL_W92.json
# /kaggle/input/openqa-questions/openqa_questions/IL_IMM_PRI_W92.json
# /kaggle/input/openqa-questions/openqa_questions/INEQ5_m_W54.json
# /kaggle/input/openqa-questions/openqa_questions/WORRYBILL_W29.json
# /kaggle/input/openqa-questions/openqa_questions/GOVPRIORITYf_W54.json
# /kaggle/input/openqa-questions/openqa_questions/IMMCULT2_W32.json
# /kaggle/input/openqa-questions/openqa_questions/INSTN_LBRUN_W92.json
# /kaggle/input/openqa-questions/openqa_questions/ESSENPOLF1G_W36.json
# /kaggle/input/openqa-questions/openqa_questions/MADEUPSHAREWHY_W45.json
# /kaggle/input/openqa-questions/openqa_questions/CARS10C_W27.json
# /kaggle/input/openqa-questions/openqa_questions/MADEUPIMPd_W45.json
# /kaggle/input/openqa-questions/openqa_questions/GOODEVIL_W92.json
# /kaggle/input/openqa-questions/openqa_questions/MADEUPSHARE1_W45.json
# /kaggle/input/openqa-questions/openqa_questions/PAR1_W50.json
# /kaggle/input/openqa-questions/openqa_questions/REASONGUNB_W26.json
# /kaggle/input/openqa-questions/openqa_questions/PROG_RRETRO_W92.json
# /kaggle/input/openqa-questions/openqa_questions/MESUM1_FA_W29.json
# /kaggle/input/openqa-questions/openqa_questions/HOMEASSIST5a_W49.json
# /kaggle/input/openqa-questions/openqa_questions/GAP21Q29_W82.json
# /kaggle/input/openqa-questions/openqa_questions/FAMSURV12_W50.json
# /kaggle/input/openqa-questions/openqa_questions/GUNACTIVITYE_W26.json
# /kaggle/input/openqa-questions/openqa_questions/GAP21Q33_g_W82.json
# /kaggle/input/openqa-questions/openqa_questions/ROBJOB3B_W27.json
# /kaggle/input/openqa-questions/openqa_questions/FEELA_W32.json
# /kaggle/input/openqa-questions/openqa_questions/RQ6_F1A_W42.json
# /kaggle/input/openqa-questions/openqa_questions/PQ4_F2Cc_W42.json
# /kaggle/input/openqa-questions/openqa_questions/MOVERURAL_W32.json
# /kaggle/input/openqa-questions/openqa_questions/ECON4_f_W54.json
# /kaggle/input/openqa-questions/openqa_questions/LOCALPROBL_F1_W32.json
# /kaggle/input/openqa-questions/openqa_questions/AVGFAM_W41.json
# /kaggle/input/openqa-questions/openqa_questions/G1_W34.json
# /kaggle/input/openqa-questions/openqa_questions/RACESURV36_W43.json
# /kaggle/input/openqa-questions/openqa_questions/SOCIETY_WHT_W92.json
# /kaggle/input/openqa-questions/openqa_questions/MED6A_W34.json
# /kaggle/input/openqa-questions/openqa_questions/BETTERBIZ1F2D_W36.json
# /kaggle/input/openqa-questions/openqa_questions/DATAUSEb_W49.json
# /kaggle/input/openqa-questions/openqa_questions/AMNTWMNBF1_W36.json
# /kaggle/input/openqa-questions/openqa_questions/INFOWHYc_W45.json
# /kaggle/input/openqa-questions/openqa_questions/RQ3_F1Cb_W42.json
# /kaggle/input/openqa-questions/openqa_questions/PQ4_F2Ba_W42.json
# /kaggle/input/openqa-questions/openqa_questions/FAMSURV23d_W50.json
# /kaggle/input/openqa-questions/openqa_questions/ECON4_h_W54.json
# /kaggle/input/openqa-questions/openqa_questions/UNDERSTANDCO_W49.json
# /kaggle/input/openqa-questions/openqa_questions/ECON5_a_W54.json
# /kaggle/input/openqa-questions/openqa_questions/RACESURV53g_W43.json
# /kaggle/input/openqa-questions/openqa_questions/PQ1_F2A_W42.json
# /kaggle/input/openqa-questions/openqa_questions/MADEUPTOPICa_W45.json
# /kaggle/input/openqa-questions/openqa_questions/SCM4a_W42.json
# /kaggle/input/openqa-questions/openqa_questions/ETHNCMAJMOD_W41.json
# /kaggle/input/openqa-questions/openqa_questions/GOVPRIOiF1_W41.json
# /kaggle/input/openqa-questions/openqa_questions/PQ3_F2Cd_W42.json
# /kaggle/input/openqa-questions/openqa_questions/MADEUPLEVELa_W45.json
# /kaggle/input/openqa-questions/openqa_questions/PWMAN2_W49.json
# /kaggle/input/openqa-questions/openqa_questions/RACESURV52MOD_W92.json
# /kaggle/input/openqa-questions/openqa_questions/ESSENBIZF2C_W36.json
# /kaggle/input/openqa-questions/openqa_questions/RACESURV5h_W43.json
# /kaggle/input/openqa-questions/openqa_questions/WHYNOTPOLF1D_W36.json
# /kaggle/input/openqa-questions/openqa_questions/CONFd_F2_W42.json
# /kaggle/input/openqa-questions/openqa_questions/HARASS1A_W32.json
# /kaggle/input/openqa-questions/openqa_questions/NEWSPREFV2_W45.json
# /kaggle/input/openqa-questions/openqa_questions/PQ4_F2Ca_W42.json
# /kaggle/input/openqa-questions/openqa_questions/INEQ5_f_W54.json
# /kaggle/input/openqa-questions/openqa_questions/GROWUPUSR_W32.json
# /kaggle/input/openqa-questions/openqa_questions/SMSHARE_W45.json
# /kaggle/input/openqa-questions/openqa_questions/COMMIMPG_W32.json
# /kaggle/input/openqa-questions/openqa_questions/MED2F_W34.json
# /kaggle/input/openqa-questions/openqa_questions/HIRING3A_W27.json
# /kaggle/input/openqa-questions/openqa_questions/ECIMPa_W54.json
# /kaggle/input/openqa-questions/openqa_questions/BOYSF1B_W29.json
# /kaggle/input/openqa-questions/openqa_questions/WHYNOTPOLF1K_W36.json
# /kaggle/input/openqa-questions/openqa_questions/MASC1F1_W29.json
# /kaggle/input/openqa-questions/openqa_questions/EVEROWN_W26.json
# /kaggle/input/openqa-questions/openqa_questions/GAP21Q33_q_W82.json
# /kaggle/input/openqa-questions/openqa_questions/FINANCEc_W54.json
# /kaggle/input/openqa-questions/openqa_questions/RQ2_F1C_W42.json
# /kaggle/input/openqa-questions/openqa_questions/TRAITPOLWF1E_W36.json
# /kaggle/input/openqa-questions/openqa_questions/TRAITPOLMF1C_W36.json
# /kaggle/input/openqa-questions/openqa_questions/FAMSURV10c_W50.json
# /kaggle/input/openqa-questions/openqa_questions/FAMSURV6_W50.json
# /kaggle/input/openqa-questions/openqa_questions/IMPROVE3_W36.json
# /kaggle/input/openqa-questions/openqa_questions/MED6B_W34.json
# /kaggle/input/openqa-questions/openqa_questions/GROWUPGUN2A_W26.json
# /kaggle/input/openqa-questions/openqa_questions/GOVPRIOjF1_W41.json
# /kaggle/input/openqa-questions/openqa_questions/EQUALBIZF2_W36.json
# /kaggle/input/openqa-questions/openqa_questions/SC1_W42.json
# /kaggle/input/openqa-questions/openqa_questions/ESSENBIZF2L_W36.json
# /kaggle/input/openqa-questions/openqa_questions/GROWUPGUN7_W26.json
# /kaggle/input/openqa-questions/openqa_questions/INCFUTURE_W32.json
# /kaggle/input/openqa-questions/openqa_questions/GAP21Q33_e_W82.json
# /kaggle/input/openqa-questions/openqa_questions/WORK4A_W27.json
# /kaggle/input/openqa-questions/openqa_questions/SOCMEDIAUSEc_W49.json
# /kaggle/input/openqa-questions/openqa_questions/CAREGIV1_W27.json
# /kaggle/input/openqa-questions/openqa_questions/GUNTYPEOWNC_W26.json
# /kaggle/input/openqa-questions/openqa_questions/PAST_W42.json
# /kaggle/input/openqa-questions/openqa_questions/FAMSURV33b_W50.json
# /kaggle/input/openqa-questions/openqa_questions/FTRWORRYa_W41.json
# /kaggle/input/openqa-questions/openqa_questions/FAMSURV21_W50.json
# /kaggle/input/openqa-questions/openqa_questions/FUD37B_W34.json
# /kaggle/input/openqa-questions/openqa_questions/INSTN_CLGS_W92.json
# /kaggle/input/openqa-questions/openqa_questions/LIFELOC_W32.json
# /kaggle/input/openqa-questions/openqa_questions/GUNLOADED2_W26.json
# /kaggle/input/openqa-questions/openqa_questions/RQ3_F1Ba_W42.json
# /kaggle/input/openqa-questions/openqa_questions/INFOKNOWc_W45.json
# /kaggle/input/openqa-questions/openqa_questions/LOCALPROBB_W32.json
# /kaggle/input/openqa-questions/openqa_questions/GAP21Q43_h_W82.json
# /kaggle/input/openqa-questions/openqa_questions/GAP21Q17_W82.json
# /kaggle/input/openqa-questions/openqa_questions/CARS10D_W27.json
# /kaggle/input/openqa-questions/openqa_questions/GAP21Q15_d_W82.json
# /kaggle/input/openqa-questions/openqa_questions/GOVPRIOc_W41.json
# /kaggle/input/openqa-questions/openqa_questions/RQ4_F1Ca_W42.json
# /kaggle/input/openqa-questions/openqa_questions/GROWUPGUN1_W26.json
# /kaggle/input/openqa-questions/openqa_questions/INEQ8_b_W54.json
# /kaggle/input/openqa-questions/openqa_questions/GUNCOURSES_W26.json
# /kaggle/input/openqa-questions/openqa_questions/NEIGHSAMEA_W32.json
# /kaggle/input/openqa-questions/openqa_questions/INEQ3_W54.json
# /kaggle/input/openqa-questions/openqa_questions/GOVRESP_d_W54.json
# /kaggle/input/openqa-questions/openqa_questions/FAMSURV30a_W50.json
# /kaggle/input/openqa-questions/openqa_questions/GAP21Q7_e_W82.json
# /kaggle/input/openqa-questions/openqa_questions/GAP21Q34_d_W82.json
# /kaggle/input/openqa-questions/openqa_questions/INFOCONFUSEc_W45.json
# /kaggle/input/openqa-questions/openqa_questions/SMLIKESb_W45.json
# /kaggle/input/openqa-questions/openqa_questions/MAN1E_W29.json
# /kaggle/input/openqa-questions/openqa_questions/GOVPRIORITYe_W54.json
# /kaggle/input/openqa-questions/openqa_questions/HARASS2F1_W32.json
# /kaggle/input/openqa-questions/openqa_questions/REPRSNTDEM_W92.json
# /kaggle/input/openqa-questions/openqa_questions/ECON4_b_W54.json
# /kaggle/input/openqa-questions/openqa_questions/SATLIFEa_W50.json
# /kaggle/input/openqa-questions/openqa_questions/ESSENBIZF2B_W36.json
# /kaggle/input/openqa-questions/openqa_questions/BETTERBIZ2F2A_W36.json
# /kaggle/input/openqa-questions/openqa_questions/BIGHOUSES_W92.json
# /kaggle/input/openqa-questions/openqa_questions/MADEUPSMFOL2_W45.json
# /kaggle/input/openqa-questions/openqa_questions/INEQ8_f_W54.json
# /kaggle/input/openqa-questions/openqa_questions/RTBFd_W49.json
# /kaggle/input/openqa-questions/openqa_questions/INSTN_LGECRP_W92.json
# /kaggle/input/openqa-questions/openqa_questions/GAP21Q4_b_W82.json
# /kaggle/input/openqa-questions/openqa_questions/NEIGHSAMEB_W32.json
# /kaggle/input/openqa-questions/openqa_questions/TRACKGOV1b_W49.json
# /kaggle/input/openqa-questions/openqa_questions/PQ7_F2C_W42.json
# /kaggle/input/openqa-questions/openqa_questions/WHYNOTPOLF1A_W36.json
# /kaggle/input/openqa-questions/openqa_questions/INFOCREATEd_W45.json
# /kaggle/input/openqa-questions/openqa_questions/BETTERPOL2F1F_W36.json
# /kaggle/input/openqa-questions/openqa_questions/PQ4_F2Be_W42.json
# /kaggle/input/openqa-questions/openqa_questions/GOVPRIOe_W41.json
# /kaggle/input/openqa-questions/openqa_questions/RQ1_F1A_W42.json
# /kaggle/input/openqa-questions/openqa_questions/PROFILE3_W49.json
# /kaggle/input/openqa-questions/openqa_questions/GODMORALIMP_W92.json
# /kaggle/input/openqa-questions/openqa_questions/CONTROLGRPe_W49.json
# /kaggle/input/openqa-questions/openqa_questions/CAREGIV6E_W27.json
# /kaggle/input/openqa-questions/openqa_questions/WORK3E_W27.json
# /kaggle/input/openqa-questions/openqa_questions/GAP21Q4_f_W82.json
# /kaggle/input/openqa-questions/openqa_questions/HARASS3F1_W41.json
# /kaggle/input/openqa-questions/openqa_questions/SMARTPHONE_W49.json
# /kaggle/input/openqa-questions/openqa_questions/LOYALTY_W49.json
# /kaggle/input/openqa-questions/openqa_questions/RACESURV19c_W43.json
# /kaggle/input/openqa-questions/openqa_questions/COMMIMPD_W32.json
# /kaggle/input/openqa-questions/openqa_questions/MARGUN_W26.json
# /kaggle/input/openqa-questions/openqa_questions/GUNRESPKIDSE_W26.json
# /kaggle/input/openqa-questions/openqa_questions/WORK7_W27.json
# /kaggle/input/openqa-questions/openqa_questions/WHYNOTBIZF2J_W36.json
# /kaggle/input/openqa-questions/openqa_questions/WRKTRN1F2_W41.json
# /kaggle/input/openqa-questions/openqa_questions/WHADVANT_W92.json
# /kaggle/input/openqa-questions/openqa_questions/BETTERBIZ2F2D_W36.json
# /kaggle/input/openqa-questions/openqa_questions/RACESURV7_W43.json
# /kaggle/input/openqa-questions/openqa_questions/PQ4_F2Ad_W42.json
# /kaggle/input/openqa-questions/openqa_questions/UNIMMIGCOMM_W92.json
# /kaggle/input/openqa-questions/openqa_questions/MESUM2_FB_W29.json
# ...
# /kaggle/input/openqa-questions/openqa_questions/TRAITBIZWF2E_W36.json
# /kaggle/input/openqa-questions/openqa_questions/GUNRESPNOKIDSG_W26.json
# /kaggle/input/openqa-questions/openqa_questions/TRAITSE_W29.json
# /kaggle/input/openqa-questions/openqa_questions/SATLIFEb_W50.json
# /kaggle/input/openqa-questions/openqa_questions/EVOBIOB_W34.json
# /kaggle/input/openqa-questions/openqa_questions/FAMSURV35c_W50.json
# /kaggle/input/openqa-questions/openqa_questions/PQ3_F2Aa_W42.json
# /kaggle/input/openqa-questions/openqa_questions/FEELC_W32.json
# /kaggle/input/openqa-questions/openqa_questions/RACESURV47a_W43.json
# /kaggle/input/openqa-questions/openqa_questions/SEENFEM_W29.json
# /kaggle/input/openqa-questions/openqa_questions/FAMSURV5b_W50.json
# /kaggle/input/openqa-questions/openqa_questions/CONFg_W42.json
# /kaggle/input/openqa-questions/openqa_questions/BETTERBIZ1F2J_W36.json
# /kaggle/input/openqa-questions/openqa_questions/CONCERNGRPa_W49.json
# /kaggle/input/openqa-questions/openqa_questions/PQ3_F2Bb_W42.json
# /kaggle/input/openqa-questions/openqa_questions/RELIG_GOV_W92.json
# /kaggle/input/openqa-questions/openqa_questions/WORRY2a_W54.json
# /kaggle/input/openqa-questions/openqa_questions/ECON5_j_W54.json
# /kaggle/input/openqa-questions/openqa_questions/BETTERPOL1F1I_W36.json
# /kaggle/input/openqa-questions/openqa_questions/GAP21Q15_c_W82.json
# /kaggle/input/openqa-questions/openqa_questions/FAMSURV30c_W50.json
# /kaggle/input/openqa-questions/openqa_questions/ECIMPg_W54.json
# /kaggle/input/openqa-questions/openqa_questions/RACESURV26_W43.json
# /kaggle/input/openqa-questions/openqa_questions/PQ4_F2Aa_W42.json
# /kaggle/input/openqa-questions/openqa_questions/VOICE5B_W27.json
# /kaggle/input/openqa-questions/openqa_questions/RACESURV47d_W43.json
# /kaggle/input/openqa-questions/openqa_questions/RACESURV5f_W43.json
# /kaggle/input/openqa-questions/openqa_questions/CARS7B_W27.json
# /kaggle/input/openqa-questions/openqa_questions/PP5c_W49.json
# /kaggle/input/openqa-questions/openqa_questions/ELITEUNDMOD_W92.json
# /kaggle/input/openqa-questions/openqa_questions/GAP21Q41_W82.json
# /kaggle/input/openqa-questions/openqa_questions/RACESURV27_W43.json
# /kaggle/input/openqa-questions/openqa_questions/GAP21Q13_c_W82.json
# /kaggle/input/openqa-questions/openqa_questions/FAMSURV33a_W50.json
# /kaggle/input/openqa-questions/openqa_questions/CARS9B_W27.json
# /kaggle/input/openqa-questions/openqa_questions/RACESURV47b_W43.json
# /kaggle/input/openqa-questions/openqa_questions/BENEFITSb_W54.json
# /kaggle/input/openqa-questions/openqa_questions/NEWS_PLATFORMg_W45.json
# /kaggle/input/openqa-questions/openqa_questions/INEQ8_h_W54.json
# /kaggle/input/openqa-questions/openqa_questions/VALUEURBAN_W32.json
# /kaggle/input/openqa-questions/openqa_questions/RACESURV5l_W43.json
# /kaggle/input/openqa-questions/openqa_questions/S13_W29.json
# /kaggle/input/openqa-questions/openqa_questions/INEQ2_W54.json
# /kaggle/input/openqa-questions/openqa_questions/INEQ5_i_W54.json
# /kaggle/input/openqa-questions/openqa_questions/ROBJOB9_W27.json
# /kaggle/input/openqa-questions/openqa_questions/FAMSURV2Ma_W50.json
# /kaggle/input/openqa-questions/openqa_questions/CONTROLGRPb_W49.json
# /kaggle/input/openqa-questions/openqa_questions/RACESURV3_W43.json
# /kaggle/input/openqa-questions/openqa_questions/TRAITPOLMF1G_W36.json
# /kaggle/input/openqa-questions/openqa_questions/ECON4_g_W54.json
# /kaggle/input/openqa-questions/openqa_questions/SOLVPROBa_W41.json
# /kaggle/input/openqa-questions/openqa_questions/HARASS1F1b_W41.json
# /kaggle/input/openqa-questions/openqa_questions/WORK5A_W27.json
# /kaggle/input/openqa-questions/openqa_questions/PQ8_F2A_W42.json
# /kaggle/input/openqa-questions/openqa_questions/FAMSURV2Md_W50.json
# /kaggle/input/openqa-questions/openqa_questions/TRAITBIZWF2F_W36.json
# /kaggle/input/openqa-questions/openqa_questions/COMPROMISEVAL_W92.json
# /kaggle/input/openqa-questions/openqa_questions/ADMISSIONf_W43.json
# /kaggle/input/openqa-questions/openqa_questions/SOCIETY_GUNS_W92.json
# /kaggle/input/openqa-questions/openqa_questions/FUD37A_W34.json
# /kaggle/input/openqa-questions/openqa_questions/FAMSURV22b_W50.json
# /kaggle/input/openqa-questions/openqa_questions/GAP21Q19_a_W82.json
# /kaggle/input/openqa-questions/openqa_questions/MED2C_W34.json
# /kaggle/input/openqa-questions/openqa_questions/NEIGHINTERB_W32.json
# /kaggle/input/openqa-questions/openqa_questions/RQ7_F1A_W42.json
# /kaggle/input/openqa-questions/openqa_questions/MAR2_W50.json
# /kaggle/input/openqa-questions/openqa_questions/LOCALPROBI_W32.json
# /kaggle/input/openqa-questions/openqa_questions/ROBJOB4A_W27.json
# /kaggle/input/openqa-questions/openqa_questions/ELDCARE_W41.json
# /kaggle/input/openqa-questions/openqa_questions/RQ5_F1C_W42.json
# /kaggle/input/openqa-questions/openqa_questions/FEELB_W32.json
# /kaggle/input/openqa-questions/openqa_questions/DATAUSEf_W49.json
# /kaggle/input/openqa-questions/openqa_questions/VOICE5C_W27.json
# /kaggle/input/openqa-questions/openqa_questions/PPLRESP_W92.json
# /kaggle/input/openqa-questions/openqa_questions/SEENMASC_W29.json
# /kaggle/input/openqa-questions/openqa_questions/MADEUPSMFOL1_W45.json
# /kaggle/input/openqa-questions/openqa_questions/GAP21Q26_a_W82.json
# /kaggle/input/openqa-questions/openqa_questions/FAMSURV27a_W50.json
# /kaggle/input/openqa-questions/openqa_questions/ROBJOB4C_W27.json
# /kaggle/input/openqa-questions/openqa_questions/TALKDISASNSINT_W49.json
# /kaggle/input/openqa-questions/openqa_questions/HARASS4_W41.json
# /kaggle/input/openqa-questions/openqa_questions/ECON4_d_W54.json
# /kaggle/input/openqa-questions/openqa_questions/GUNCONTRIBB_W26.json
# /kaggle/input/openqa-questions/openqa_questions/ECON4_e_W54.json
# /kaggle/input/openqa-questions/openqa_questions/CANQUALPOL_W92.json
# /kaggle/input/openqa-questions/openqa_questions/CONCERNGRPd_W49.json
# /kaggle/input/openqa-questions/openqa_questions/FAMSURV2Mb_W50.json
# /kaggle/input/openqa-questions/openqa_questions/DNATEST_W49.json
# /kaggle/input/openqa-questions/openqa_questions/FAMSURV20_W50.json
# /kaggle/input/openqa-questions/openqa_questions/SOLVPROBf_W41.json
# /kaggle/input/openqa-questions/openqa_questions/GOODJOBS_W29.json
# /kaggle/input/openqa-questions/openqa_questions/ROBJOB7_W27.json
# /kaggle/input/openqa-questions/openqa_questions/FAMSURV38a_W50.json
# /kaggle/input/openqa-questions/openqa_questions/SOLVPROBh_W41.json
# /kaggle/input/openqa-questions/openqa_questions/GAP21Q28_W82.json
# /kaggle/input/openqa-questions/openqa_questions/GAP21Q15_f_W82.json
# /kaggle/input/openqa-questions/openqa_questions/CNTRYFAIR_W92.json
# /kaggle/input/openqa-questions/openqa_questions/NEWSPROBc_W45.json
# /kaggle/input/openqa-questions/openqa_questions/LOCALPROBM_F2_W32.json
# /kaggle/input/openqa-questions/openqa_questions/FAMSURV35b_W50.json
# /kaggle/input/openqa-questions/openqa_questions/FATHER_W50.json
# /kaggle/input/openqa-questions/openqa_questions/GROWUPGUN2B_W26.json
# /kaggle/input/openqa-questions/openqa_questions/HOMEASSIST3_W49.json
# /kaggle/input/openqa-questions/openqa_questions/GAP21Q33_r_W82.json
# /kaggle/input/openqa-questions/openqa_questions/WORK3D_W27.json
# /kaggle/input/openqa-questions/openqa_questions/DIGWDOG_3_W45.json
# /kaggle/input/openqa-questions/openqa_questions/SATLIFEA_W32.json
# /kaggle/input/openqa-questions/openqa_questions/WORK4C_W27.json
# /kaggle/input/openqa-questions/openqa_questions/MEDIALOYAL3_W45.json
# /kaggle/input/openqa-questions/openqa_questions/GUNCONTRIBC_W26.json
# /kaggle/input/openqa-questions/openqa_questions/PQ3_F2Cb_W42.json
# /kaggle/input/openqa-questions/openqa_questions/HARASS1C_W32.json
# /kaggle/input/openqa-questions/openqa_questions/FERTIL1_W36.json
# /kaggle/input/openqa-questions/openqa_questions/FACE4d_W49.json
# /kaggle/input/openqa-questions/openqa_questions/FAMSURV36c_W50.json
# /kaggle/input/openqa-questions/openqa_questions/HAPPENhF1_W41.json
# /kaggle/input/openqa-questions/openqa_questions/ESSENBIZF2I_W36.json
# /kaggle/input/openqa-questions/openqa_questions/IMMCOMM_W32.json
# /kaggle/input/openqa-questions/openqa_questions/INEQ4_d_W54.json
# /kaggle/input/openqa-questions/openqa_questions/GIRLSF2A_W29.json
# /kaggle/input/openqa-questions/openqa_questions/RACATTN_W43.json
# /kaggle/input/openqa-questions/openqa_questions/EAT3G_W34.json
# /kaggle/input/openqa-questions/openqa_questions/RACESURV19e_W43.json
# /kaggle/input/openqa-questions/openqa_questions/WHYNOTPOLF1C_W36.json
# /kaggle/input/openqa-questions/openqa_questions/Q6F2_W42.json
# /kaggle/input/openqa-questions/openqa_questions/ROBJOB8C_W27.json
# /kaggle/input/openqa-questions/openqa_questions/NEIGHKNOW_W32.json
# /kaggle/input/openqa-questions/openqa_questions/RACESURV44_W43.json
# /kaggle/input/openqa-questions/openqa_questions/LOCALPROBJ_W32.json
# /kaggle/input/openqa-questions/openqa_questions/FAMSURV26a_W50.json
# /kaggle/input/openqa-questions/openqa_questions/FP_AUTH_W92.json
# /kaggle/input/openqa-questions/openqa_questions/GAP21Q33_a_W82.json
# /kaggle/input/openqa-questions/openqa_questions/LIFEFIFTY_W92.json
# /kaggle/input/openqa-questions/openqa_questions/MADEUPRESe_W45.json
# /kaggle/input/openqa-questions/openqa_questions/GAP21Q7_d_W82.json
# /kaggle/input/openqa-questions/openqa_questions/GAP21Q43_b_W82.json
# /kaggle/input/openqa-questions/openqa_questions/CARS9C_W27.json
# /kaggle/input/openqa-questions/openqa_questions/SCM5d_W42.json
# /kaggle/input/openqa-questions/openqa_questions/ADMISSIONb_W43.json
# /kaggle/input/openqa-questions/openqa_questions/JOBSFUTURE_W32.json
# /kaggle/input/openqa-questions/openqa_questions/ECONFAIR2_W32.json
# /kaggle/input/openqa-questions/openqa_questions/GAP21Q4_d_W82.json
# /kaggle/input/openqa-questions/openqa_questions/HELPHURTG_W29.json
# /kaggle/input/openqa-questions/openqa_questions/RACESURV53f_W43.json
# /kaggle/input/openqa-questions/openqa_questions/FAMSURV43_W50.json
# /kaggle/input/openqa-questions/openqa_questions/MED4B_W34.json
# /kaggle/input/openqa-questions/openqa_questions/ESSENBIZF2F_W36.json
# /kaggle/input/openqa-questions/openqa_questions/EAT6_W34.json
# /kaggle/input/openqa-questions/openqa_questions/HARASS4_W32.json
# /kaggle/input/openqa-questions/openqa_questions/PP5d_W49.json
# /kaggle/input/openqa-questions/openqa_questions/RTDa_W49.json
# /kaggle/input/openqa-questions/openqa_questions/CARS8_W27.json
# /kaggle/input/openqa-questions/openqa_questions/MED2B_W34.json
# /kaggle/input/openqa-questions/openqa_questions/CONCERNGRPb_W49.json
# /kaggle/input/openqa-questions/openqa_questions/FAMSURV2Mc_W50.json
# /kaggle/input/openqa-questions/openqa_questions/RQ4_F1Aa_W42.json
# /kaggle/input/openqa-questions/openqa_questions/NEWSPROBa_W45.json
# /kaggle/input/openqa-questions/openqa_questions/GUNACTIVITYB_W26.json
# /kaggle/input/openqa-questions/openqa_questions/Q6F1_W42.json
# /kaggle/input/openqa-questions/openqa_questions/MAN1C_W29.json
# /kaggle/input/openqa-questions/openqa_questions/TRAITBIZWF2A_W36.json
# /kaggle/input/openqa-questions/openqa_questions/EVOPERS3A_W34.json
# /kaggle/input/openqa-questions/openqa_questions/FAMSURV25_W50.json
# /kaggle/input/openqa-questions/openqa_questions/VTRS_VALS_W92.json
# /kaggle/input/openqa-questions/openqa_questions/INFOOWNb_W45.json
# /kaggle/input/openqa-questions/openqa_questions/RACESURV6_W43.json
# /kaggle/input/openqa-questions/openqa_questions/REASONGUNA_W26.json
# /kaggle/input/openqa-questions/openqa_questions/RQ4_F1Ce_W42.json
# /kaggle/input/openqa-questions/openqa_questions/VOICE5D_W27.json
# /kaggle/input/openqa-questions/openqa_questions/HIRING4_W27.json
# /kaggle/input/openqa-questions/openqa_questions/ROBJOB4E_W27.json
# /kaggle/input/openqa-questions/openqa_questions/PQ5_F2A_W42.json
# /kaggle/input/openqa-questions/openqa_questions/FAMSURV23f_W50.json
# /kaggle/input/openqa-questions/openqa_questions/FAMSURV44_W50.json
# /kaggle/input/openqa-questions/openqa_questions/COMTYPE2_W32.json
# /kaggle/input/openqa-questions/openqa_questions/CONTROLGOV_W49.json
# /kaggle/input/openqa-questions/openqa_questions/AUTOLKLY_W41.json
# /kaggle/input/openqa-questions/openqa_questions/SPOUSESEX_W50.json
# /kaggle/input/openqa-questions/openqa_questions/SPOUSESEX_W29.json
# /kaggle/input/openqa-questions/openqa_questions/MISINFG_W32.json
# /kaggle/input/openqa-questions/openqa_questions/BUSPROFIT_W92.json
# /kaggle/input/openqa-questions/openqa_questions/DIFF1E_W29.json
# /kaggle/input/openqa-questions/openqa_questions/DIFF1D_W29.json
# /kaggle/input/openqa-questions/openqa_questions/DATAUSEe_W49.json
# /kaggle/input/openqa-questions/openqa_questions/GUNCONTRIBA_W26.json
# /kaggle/input/openqa-questions/openqa_questions/GOVREGV2_W49.json
# /kaggle/input/openqa-questions/openqa_questions/ELECT_IMPT3_PRVFR_W92.json
# /kaggle/input/openqa-questions/openqa_questions/RACESURV51_W43.json
# /kaggle/input/openqa-questions/openqa_questions/SSMONEY_W41.json
# /kaggle/input/openqa-questions/openqa_questions/GUNRESPKIDSA_W26.json
# /kaggle/input/openqa-questions/openqa_questions/LWPSP_W50.json
# /kaggle/input/openqa-questions/openqa_questions/FAMSURV30d_W50.json
# /kaggle/input/openqa-questions/openqa_questions/HARASS1D_W32.json
# /kaggle/input/openqa-questions/openqa_questions/INFORESTRICTc_W45.json
# /kaggle/input/openqa-questions/openqa_questions/WORK3F_W27.json
# /kaggle/input/openqa-questions/openqa_questions/RACESURV28a_W43.json
# /kaggle/input/openqa-questions/openqa_questions/EVOONE_W34.json
# /kaggle/input/openqa-questions/openqa_questions/GAP21Q21_c_W82.json
# /kaggle/input/openqa-questions/openqa_questions/GAP21Q4_e_W82.json
# /kaggle/input/openqa-questions/openqa_questions/GAP21Q37_W82.json
# /kaggle/input/openqa-questions/openqa_questions/UNDERSTANDGOV_W49.json
# /kaggle/input/openqa-questions/openqa_questions/INEQ5_g_W54.json
# /kaggle/input/openqa-questions/openqa_questions/TRAITPOLMF1F_W36.json
# /kaggle/input/openqa-questions/openqa_questions/FINANCEb_W54.json
# /kaggle/input/openqa-questions/openqa_questions/HARASS5_W41.json
# /kaggle/input/openqa-questions/openqa_questions/FAMSURV1_W50.json
# /kaggle/input/openqa-questions/openqa_questions/FAMSURV37_W50.json
# /kaggle/input/openqa-questions/openqa_questions/EAT3K_W34.json
# /kaggle/input/openqa-questions/openqa_questions/MED3_W34.json
# /kaggle/input/openqa-questions/openqa_questions/GUNRESPKIDSC_W26.json
# /kaggle/input/openqa-questions/openqa_questions/INEQ8_j_W54.json
# /kaggle/input/openqa-questions/openqa_questions/SCI2A_W34.json
# /kaggle/input/openqa-questions/openqa_questions/ESSENPOLF1I_W36.json
# /kaggle/input/openqa-questions/openqa_questions/GUNIDENTITY_W26.json
# /kaggle/input/openqa-questions/openqa_questions/ELDFINANCEF2_W41.json
# /kaggle/input/openqa-questions/openqa_questions/RACESURV18b_W43.json
# /kaggle/input/openqa-questions/openqa_questions/WORLDDANGER_W26.json
# /kaggle/input/openqa-questions/openqa_questions/HAPPEN2b_W41.json
# /kaggle/input/openqa-questions/openqa_questions/GUNRESPNOKIDSA_W26.json
# /kaggle/input/openqa-questions/openqa_questions/INDUSTRY_W27.json
# /kaggle/input/openqa-questions/openqa_questions/GAP21Q2_W82.json
# /kaggle/input/openqa-questions/openqa_questions/INEQ4_a_W54.json
# /kaggle/input/openqa-questions/openqa_questions/CARRYGUN_W26.json
# /kaggle/input/openqa-questions/openqa_questions/RACESURV18c_W43.json
# /kaggle/input/openqa-questions/openqa_questions/GAP21Q19_e_W82.json
# /kaggle/input/openqa-questions/openqa_questions/RACESURV9_W43.json
# /kaggle/input/openqa-questions/openqa_questions/BILLION_W92.json
# /kaggle/input/openqa-questions/openqa_questions/RACESURV29a_W43.json
# /kaggle/input/openqa-questions/openqa_questions/CAREGIV6D_W27.json
# /kaggle/input/openqa-questions/openqa_questions/ROBJOB8E_W27.json
# /kaggle/input/openqa-questions/openqa_questions/WHYNOTPOLF1F_W36.json
# /kaggle/input/openqa-questions/openqa_questions/FIN_SITCOMM_W54.json
# /kaggle/input/openqa-questions/openqa_questions/DB1b_W49.json
# /kaggle/input/openqa-questions/openqa_questions/RQ4_F1Ad_W42.json
# /kaggle/input/openqa-questions/openqa_questions/PP6c_W49.json
# /kaggle/input/openqa-questions/openqa_questions/ABORTIONALLOW_W32.json
# /kaggle/input/openqa-questions/openqa_questions/RACESURV1d_W43.json
# /kaggle/input/openqa-questions/openqa_questions/DATAUSEa_W49.json
# /kaggle/input/openqa-questions/openqa_questions/GOVRESP_e_W54.json

# %%
from huggingface_hub import login


login('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')
# Out:
# The token has not been saved to the git credentials helper. Pass `add_to_git_credential=True` in this function directly or `--add-to-git-credential` if using via `huggingface-cli` if you want to set the git credential as well.
# Token is valid (permission: read).
# Your token has been saved to /root/.cache/huggingface/token
# Login successful

# %%
# !pip install -U bitsandbytes accelerate
# Out:
# Collecting bitsandbytes
#   Downloading bitsandbytes-0.44.1-py3-none-manylinux_2_24_x86_64.whl.metadata (3.5 kB)
# Requirement already satisfied: accelerate in /opt/conda/lib/python3.10/site-packages (0.34.2)
# Collecting accelerate
#   Downloading accelerate-1.0.1-py3-none-any.whl.metadata (19 kB)
# Requirement already satisfied: torch in /opt/conda/lib/python3.10/site-packages (from bitsandbytes) (2.4.0)
# Requirement already satisfied: numpy in /opt/conda/lib/python3.10/site-packages (from bitsandbytes) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /opt/conda/lib/python3.10/site-packages (from accelerate) (21.3)
# Requirement already satisfied: psutil in /opt/conda/lib/python3.10/site-packages (from accelerate) (5.9.3)
# Requirement already satisfied: pyyaml in /opt/conda/lib/python3.10/site-packages (from accelerate) (6.0.2)
# Requirement already satisfied: huggingface-hub>=0.21.0 in /opt/conda/lib/python3.10/site-packages (from accelerate) (0.25.1)
# Requirement already satisfied: safetensors>=0.4.3 in /opt/conda/lib/python3.10/site-packages (from accelerate) (0.4.5)
# Requirement already satisfied: filelock in /opt/conda/lib/python3.10/site-packages (from huggingface-hub>=0.21.0->accelerate) (3.15.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /opt/conda/lib/python3.10/site-packages (from huggingface-hub>=0.21.0->accelerate) (2024.6.1)
# Requirement already satisfied: requests in /opt/conda/lib/python3.10/site-packages (from huggingface-hub>=0.21.0->accelerate) (2.32.3)
# Requirement already satisfied: tqdm>=4.42.1 in /opt/conda/lib/python3.10/site-packages (from huggingface-hub>=0.21.0->accelerate) (4.66.4)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /opt/conda/lib/python3.10/site-packages (from huggingface-hub>=0.21.0->accelerate) (4.12.2)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /opt/conda/lib/python3.10/site-packages (from packaging>=20.0->accelerate) (3.1.2)
# Requirement already satisfied: sympy in /opt/conda/lib/python3.10/site-packages (from torch->bitsandbytes) (1.13.3)
# Requirement already satisfied: networkx in /opt/conda/lib/python3.10/site-packages (from torch->bitsandbytes) (3.3)
# Requirement already satisfied: jinja2 in /opt/conda/lib/python3.10/site-packages (from torch->bitsandbytes) (3.1.4)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.10/site-packages (from jinja2->torch->bitsandbytes) (2.1.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests->huggingface-hub>=0.21.0->accelerate) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests->huggingface-hub>=0.21.0->accelerate) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests->huggingface-hub>=0.21.0->accelerate) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests->huggingface-hub>=0.21.0->accelerate) (2024.8.30)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /opt/conda/lib/python3.10/site-packages (from sympy->torch->bitsandbytes) (1.3.0)
# Downloading bitsandbytes-0.44.1-py3-none-manylinux_2_24_x86_64.whl (122.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 122.4/122.4 MB 13.4 MB/s eta 0:00:0000:0100:01
# Downloading accelerate-1.0.1-py3-none-any.whl (330 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 330.9/330.9 kB 21.7 MB/s eta 0:00:00
# Installing collected packages: bitsandbytes, accelerate
#   Attempting uninstall: accelerate
#     Found existing installation: accelerate 0.34.2
#     Uninstalling accelerate-0.34.2:
#       Successfully uninstalled accelerate-0.34.2
# Successfully installed accelerate-1.0.1 bitsandbytes-0.44.1

# %%
from transformers import AutoTokenizer, AutoModelForCausalLM, BitsAndBytesConfig
import torch

def get_models(model_names, configs):
    models = []
    tokenizers = []
    for md_name, conf in zip(model_names, configs):
        model = AutoModelForCausalLM.from_pretrained(
            md_name,
            quantization_config = conf,
            torch_dtype = torch.float16,
            device_map = 'auto',
            trust_remote_code = True
        )
        
        tokenizer = AutoTokenizer.from_pretrained(md_name)
        
        models.append(model)
        tokenizers.append(tokenizer)
    
    return models, tokenizers

# %%
fourbitConfig = BitsAndBytesConfig(
    load_in_4bit = True,
    bnb_4bit_quanty_type = "fp4", 
    bnb_4bit_compute_dtype=torch.float16,
    bnb_4bit_use_double_quanty = True,
)

model_strs = [
    'falcon_11b',
]

model_names = [
    'tiiuae/falcon-11b',
]

quant_configs = [
    fourbitConfig,
    fourbitConfig,
    fourbitConfig

]

needs_devices = [config is None for config in quant_configs]

models, tokenizers = get_models(model_names, quant_configs)
# Out:
# Unused kwargs: ['bnb_4bit_quanty_type', 'bnb_4bit_use_double_quanty']. These kwargs are not used in <class 'transformers.utils.quantization_config.BitsAndBytesConfig'>.
# config.json:   0%|          | 0.00/1.39k [00:00<?, ?B/s]
# configuration_falcon.py:   0%|          | 0.00/9.25k [00:00<?, ?B/s]
# A new version of the following files was downloaded from https://huggingface.co/tiiuae/falcon-11B:
# - configuration_falcon.py
# . Make sure to double-check they do not contain any added malicious code. To avoid downloading new versions of the code file, you can pin a revision.
# modeling_falcon.py:   0%|          | 0.00/76.7k [00:00<?, ?B/s]
# A new version of the following files was downloaded from https://huggingface.co/tiiuae/falcon-11B:
# - modeling_falcon.py
# . Make sure to double-check they do not contain any added malicious code. To avoid downloading new versions of the code file, you can pin a revision.
# model.safetensors.index.json:   0%|          | 0.00/31.5k [00:00<?, ?B/s]
# Downloading shards:   0%|          | 0/5 [00:00<?, ?it/s]
# model-00001-of-00005.safetensors:   0%|          | 0.00/4.98G [00:00<?, ?B/s]
# model-00002-of-00005.safetensors:   0%|          | 0.00/4.93G [00:00<?, ?B/s]
# model-00003-of-00005.safetensors:   0%|          | 0.00/4.93G [00:00<?, ?B/s]
# model-00004-of-00005.safetensors:   0%|          | 0.00/4.93G [00:00<?, ?B/s]
# model-00005-of-00005.safetensors:   0%|          | 0.00/2.43G [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/5 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/113 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/3.30k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/2.73M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/448 [00:00<?, ?B/s]

# %%
def get_distribution(prompt, expected_answers) -> dict:
    input_ids = tokenizer.encode(prompt, return_tensors='pt')
    
    with torch.no_grad():
        outputs = model(input_ids)
        logits = outputs.logits[:, -1, :]  # Get logits for the last token

    # Calculate probabilities and log probabilities
    probabilities = torch.softmax(logits, dim=-1)
    log_probs = torch.log(probabilities)

    # Get top k candidates
    top_k = 100 
    top_probabilities, top_indices = torch.topk(log_probs, top_k)

    # Decode the top tokens to words
    top_words = tokenizer.convert_ids_to_tokens(top_indices[0].tolist())

    # Display results
    probabilities = {}
    for word, prob in zip(top_words, top_probabilities[0].tolist()):
        # print(f"Word: {word}, Log Probability: {prob:.4f}")
        probabilities[word] = prob
    
    distribution = {}
    for ans in expected_answers:
        if ans in probabilities:
            distribution[ans] = probabilities[ans]
    
    # distribution = {k:probabilities[k] for k in expected_answers}
    
    return distribution

# %%
def generate_prompts(q_dict, context=None, context_type=None):
    context_str = ''
    if context is not None:
        if context_type == 'QA':
            context_options = {'democrat': '1', 'republican': '2', 'independent': '3',
                              'other': '4', 'refused': '5'}
            option = context_options.get(context.strip().lower(), '4')
            context_str = f"""
Question: In politics today do you consider yourself a
1. Democrat
2. Republican
3. Independent
4. Other
5. Refused
Answer: {option}
"""
        elif context_type == 'BIO':
            context_str = f"""
Below you will be asked to provide a short description of your political ideology and then answer some questions.
Description: I identify as a {context.strip().title()}.
"""
        
        elif context_type == 'PORTRAY':
            context_str = f"""
Answer the following question as if you identified as a {context.strip().title()}.
"""
    
    main_question = q_dict['main_question']
    sub_questions = q_dict['sub_questions']
    
    expected_answers = [str(ans["id"]) for ans in q_dict["answers"]]
    if not sub_questions:
        prompt = f"""
{context_str}

Question: {main_question}
"""
        
        for ans in q_dict['answers']:
            prompt += f"{ans['id']}: {ans['text']}\n"
        prompt += f"Answer: "
        return [prompt], expected_answers
    
    prompts = []
    for sq in sub_questions:
        prompt = f"""
{context_str}

Question: {main_question}
{sq['id']}: {sq['text']}
"""
        for ans in q_dict['answers']:
            prompt += f"{ans['id']}: {ans['text']}\n"
        prompt += f"Answer: "
        prompts.append(prompt)
    
    return prompts, expected_answers

# %%
def get_distribution(prompt, expected_answers, q_dict, model, tokenizer, needs_device) -> dict:
    input_ids = tokenizer.encode(prompt, return_tensors='pt')
    
    if needs_device:
        device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
        model = model.to(device)
        input_ids = input_ids.to(device)
        
    with torch.no_grad():
        outputs = model(input_ids)
        logits = outputs.logits[:, -1, :]  # Get logits for the last token

    # Calculate probabilities and log probabilities
    probabilities = torch.softmax(logits, dim=-1)
    log_probs = torch.log(probabilities)

    # Get top k candidates
    top_k = 100 
    top_probabilities, top_indices = torch.topk(log_probs, top_k)

    # Decode the top tokens to words
    top_words = tokenizer.convert_ids_to_tokens(top_indices[0].tolist())

    # Display results
    probabilities = {}
    for word, prob in zip(top_words, top_probabilities[0].tolist()):
        # print(f"Word: {word}, Log Probability: {prob:.4f}")
        probabilities[word] = prob
    
    distribution = {}
    answers = q_dict['answers']
    for ans in expected_answers:
        if ans in probabilities:
            for a in answers:
                if a['id'] == int(ans):
                    distribution[a['text']] = probabilities[ans]
                    break
            
    # distribution = {k:probabilities[k] for k in expected_answers}
    return distribution

# %%
import os

openqa_paths = os.listdir("/kaggle/input/openqa-questions/openqa_questions")

question_codes = [s[:-5] for s in openqa_paths]

# %%
FORM_NO = 'W26'

# %%
import json



# Open the JSONL file in write mode
# Open the JSONL file in write mode
for model_str, model, tokenizer, n_device in zip(model_strs, models, tokenizers, needs_devices):
    print(model_str)
    print()
    print()

    with open(f'/kaggle/working/output_{model_str}.jsonl', 'w') as jsonl_file:
        for i, qc in enumerate(question_codes, start=1):
            if FORM_NO not in qc:
                continue
            # Hindu, Muslim, Christian, Sikh, Buddhist, Jain, Parsi
            for c in [None]:
                for ctype in [None]:
                    with open(f'/kaggle/input/openqa-questions/openqa_questions/{qc}.json') as f:
                        q = json.load(f)

                    prompts, expected_answers = generate_prompts(q, c, ctype)

                    for idx, prompt in enumerate(prompts):
                        dist = get_distribution(prompt, expected_answers, q, model, tokenizer, n_device)

                        # Create a unique ID (e.g., using `i`, `c`, `ctype`, and `idx` for uniqueness)
                        unique_id = f"{qc}_{c}_{ctype}"
                        print(unique_id)

                        # Create the JSON object
                        json_obj = {
                            'id': unique_id,
                            'question_number': i,
                            'context': c,
                            'context_type': ctype,
                            'prompt': prompt,
                            'distribution': dist
                        }

                        # Write the JSON object as a line in the JSONL file
                        jsonl_file.write(json.dumps(json_obj) + '\n')
# Out:
# falcon_11b
#
#
# WORRYD_W26_None_None
# REASONGUND_W26_None_None
# GUNLOADED1_W26_None_None
# GUNRESPKIDSF_W26_None_None
# GUNSOCIETY_W26_None_None
# GUNACTIVITYA_W26_None_None
# GUN1_W26_None_None
# GUNACTIVITYD_W26_None_None
# GUNSAFETYKIDS_W26_None_None
# GUNKILLF1_W26_None_None
# WORRYE_W26_None_None
# GUNASSOCIATIONA_W26_None_None
# GROWUPGUN2C_W26_None_None
# CRIMEVICTIM_W26_None_None
# GUNRESPNOKIDSF_W26_None_None
# GUNSAFE2_W26_None_None
# REASONGUNC_W26_None_None
# GROWUPGUN6_W26_None_None
# GUNCONTRIBF_W26_None_None
# GUNRESPKIDSB_W26_None_None
# GUNRESPNOKIDSB_W26_None_None
# WORRYF_W26_None_None
# GROWUPVIOL_W26_None_None
# DEFENDGUN_W26_None_None
# WORRYB_W26_None_None
# REASONGUNB_W26_None_None
# GUNACTIVITYE_W26_None_None
# EVEROWN_W26_None_None
# GROWUPGUN2A_W26_None_None
# GROWUPGUN7_W26_None_None
# GUNTYPEOWNC_W26_None_None
# GUNLOADED2_W26_None_None
# GROWUPGUN1_W26_None_None
# GUNCOURSES_W26_None_None
# MARGUN_W26_None_None
# GUNRESPKIDSE_W26_None_None
# GUNRESPKIDSG_W26_None_None
# GUNACCESS_W26_None_None
# GUNLOCKED1_W26_None_None
# SHOOTFREQ_W26_None_None
# GUNRESPNOKIDSC_W26_None_None
# GUNCOMMUNITY_W26_None_None
# NOCARRYGUN_W26_None_None
# GUNRESPKIDSH_W26_None_None
# GUNRESPKIDSD_W26_None_None
# GROWUPGUN4_W26_None_None
# WORRYC_W26_None_None
# GUNACTIVITYC_W26_None_None
# GUNLOCKED2_W26_None_None
# WORRYG_W26_None_None
# GUNSAFE_W26_None_None
# SAFECRIME_W26_None_None
# REASONGUNE_W26_None_None
# GUNCONTRIBE_W26_None_None
# GUNFRIEND_W26_None_None
# EVERSHOT_W26_None_None
# GUNRESPNOKIDSD_W26_None_None
# GUNCONTRIBD_W26_None_None
# WORRYA_W26_None_None
# GUNTHREAT_W26_None_None
# GUNRESPNOKIDSE_W26_None_None
# IMPREASONGUN_W26_None_None
# GUN_W26_None_None
# GUNKILLF2_W26_None_None
# NEVEROWN_W26_None_None
# GUNRESPNOKIDSG_W26_None_None
# GUNCONTRIBB_W26_None_None
# GROWUPGUN2B_W26_None_None
# GUNCONTRIBC_W26_None_None
# GUNACTIVITYB_W26_None_None
# REASONGUNA_W26_None_None
# GUNCONTRIBA_W26_None_None
# GUNRESPKIDSA_W26_None_None
# GUNRESPKIDSC_W26_None_None
# GUNIDENTITY_W26_None_None
# WORLDDANGER_W26_None_None
# GUNRESPNOKIDSA_W26_None_None
# CARRYGUN_W26_None_None

# %%
import json



# Open the JSONL file in write mode
# Open the JSONL file in write mode
for model_str, model, tokenizer, n_device in zip(model_strs, models, tokenizers, needs_devices):
    print(model_str)
    print()
    print()

    with open(f'/kaggle/working/output_politicalContext_{model_str}.jsonl', 'w') as jsonl_file:
        for i, qc in enumerate(question_codes, start=1):
            if FORM_NO not in qc:
                continue
            # Hindu, Muslim, Christian, Sikh, Buddhist, Jain, Parsi
            for c in ['democrat', 'republican', 'independent']:
                for ctype in ['QA', 'BIO', 'PORTRAY']:
                    with open(f'/kaggle/input/openqa-questions/openqa_questions/{qc}.json') as f:
                        q = json.load(f)

                    prompts, expected_answers = generate_prompts(q, c, ctype)

                    for idx, prompt in enumerate(prompts):
                        dist = get_distribution(prompt, expected_answers, q, model, tokenizer, n_device)

                        # Create a unique ID (e.g., using `i`, `c`, `ctype`, and `idx` for uniqueness)
                        unique_id = f"{qc}_{c}_{ctype}"
                        print(unique_id)

                        # Create the JSON object
                        json_obj = {
                            'id': unique_id,
                            'question_number': i,
                            'context': c,
                            'context_type': ctype,
                            'prompt': prompt,
                            'distribution': dist
                        }

                        # Write the JSON object as a line in the JSONL file
                        jsonl_file.write(json.dumps(json_obj) + '\n')
# Out:
# falcon_11b
#
#
# WORRYD_W26_democrat_QA
# WORRYD_W26_democrat_BIO
# WORRYD_W26_democrat_PORTRAY
# WORRYD_W26_republican_QA
# WORRYD_W26_republican_BIO
# WORRYD_W26_republican_PORTRAY
# WORRYD_W26_independent_QA
# WORRYD_W26_independent_BIO
# WORRYD_W26_independent_PORTRAY
# REASONGUND_W26_democrat_QA
# REASONGUND_W26_democrat_BIO
# REASONGUND_W26_democrat_PORTRAY
# REASONGUND_W26_republican_QA
# REASONGUND_W26_republican_BIO
# REASONGUND_W26_republican_PORTRAY
# REASONGUND_W26_independent_QA
# REASONGUND_W26_independent_BIO
# REASONGUND_W26_independent_PORTRAY
# GUNLOADED1_W26_democrat_QA
# GUNLOADED1_W26_democrat_BIO
# GUNLOADED1_W26_democrat_PORTRAY
# GUNLOADED1_W26_republican_QA
# GUNLOADED1_W26_republican_BIO
# GUNLOADED1_W26_republican_PORTRAY
# GUNLOADED1_W26_independent_QA
# GUNLOADED1_W26_independent_BIO
# GUNLOADED1_W26_independent_PORTRAY
# GUNRESPKIDSF_W26_democrat_QA
# GUNRESPKIDSF_W26_democrat_BIO
# GUNRESPKIDSF_W26_democrat_PORTRAY
# GUNRESPKIDSF_W26_republican_QA
# GUNRESPKIDSF_W26_republican_BIO
# GUNRESPKIDSF_W26_republican_PORTRAY
# GUNRESPKIDSF_W26_independent_QA
# GUNRESPKIDSF_W26_independent_BIO
# GUNRESPKIDSF_W26_independent_PORTRAY
# GUNSOCIETY_W26_democrat_QA
# GUNSOCIETY_W26_democrat_BIO
# GUNSOCIETY_W26_democrat_PORTRAY
# GUNSOCIETY_W26_republican_QA
# GUNSOCIETY_W26_republican_BIO
# GUNSOCIETY_W26_republican_PORTRAY
# GUNSOCIETY_W26_independent_QA
# GUNSOCIETY_W26_independent_BIO
# GUNSOCIETY_W26_independent_PORTRAY
# GUNACTIVITYA_W26_democrat_QA
# GUNACTIVITYA_W26_democrat_BIO
# GUNACTIVITYA_W26_democrat_PORTRAY
# GUNACTIVITYA_W26_republican_QA
# GUNACTIVITYA_W26_republican_BIO
# GUNACTIVITYA_W26_republican_PORTRAY
# GUNACTIVITYA_W26_independent_QA
# GUNACTIVITYA_W26_independent_BIO
# GUNACTIVITYA_W26_independent_PORTRAY
# GUN1_W26_democrat_QA
# GUN1_W26_democrat_BIO
# GUN1_W26_democrat_PORTRAY
# GUN1_W26_republican_QA
# GUN1_W26_republican_BIO
# GUN1_W26_republican_PORTRAY
# GUN1_W26_independent_QA
# GUN1_W26_independent_BIO
# GUN1_W26_independent_PORTRAY
# GUNACTIVITYD_W26_democrat_QA
# GUNACTIVITYD_W26_democrat_BIO
# GUNACTIVITYD_W26_democrat_PORTRAY
# GUNACTIVITYD_W26_republican_QA
# GUNACTIVITYD_W26_republican_BIO
# GUNACTIVITYD_W26_republican_PORTRAY
# GUNACTIVITYD_W26_independent_QA
# GUNACTIVITYD_W26_independent_BIO
# GUNACTIVITYD_W26_independent_PORTRAY
# GUNSAFETYKIDS_W26_democrat_QA
# GUNSAFETYKIDS_W26_democrat_BIO
# GUNSAFETYKIDS_W26_democrat_PORTRAY
# GUNSAFETYKIDS_W26_republican_QA
# GUNSAFETYKIDS_W26_republican_BIO
# GUNSAFETYKIDS_W26_republican_PORTRAY
# GUNSAFETYKIDS_W26_independent_QA
# GUNSAFETYKIDS_W26_independent_BIO
# GUNSAFETYKIDS_W26_independent_PORTRAY
# GUNKILLF1_W26_democrat_QA
# GUNKILLF1_W26_democrat_BIO
# GUNKILLF1_W26_democrat_PORTRAY
# GUNKILLF1_W26_republican_QA
# GUNKILLF1_W26_republican_BIO
# GUNKILLF1_W26_republican_PORTRAY
# GUNKILLF1_W26_independent_QA
# GUNKILLF1_W26_independent_BIO
# GUNKILLF1_W26_independent_PORTRAY
# WORRYE_W26_democrat_QA
# WORRYE_W26_democrat_BIO
# WORRYE_W26_democrat_PORTRAY
# WORRYE_W26_republican_QA
# WORRYE_W26_republican_BIO
# WORRYE_W26_republican_PORTRAY
# WORRYE_W26_independent_QA
# WORRYE_W26_independent_BIO
# WORRYE_W26_independent_PORTRAY
# GUNASSOCIATIONA_W26_democrat_QA
# GUNASSOCIATIONA_W26_democrat_BIO
# GUNASSOCIATIONA_W26_democrat_PORTRAY
# GUNASSOCIATIONA_W26_republican_QA
# GUNASSOCIATIONA_W26_republican_BIO
# GUNASSOCIATIONA_W26_republican_PORTRAY
# GUNASSOCIATIONA_W26_independent_QA
# GUNASSOCIATIONA_W26_independent_BIO
# GUNASSOCIATIONA_W26_independent_PORTRAY
# GROWUPGUN2C_W26_democrat_QA
# GROWUPGUN2C_W26_democrat_BIO
# GROWUPGUN2C_W26_democrat_PORTRAY
# GROWUPGUN2C_W26_republican_QA
# GROWUPGUN2C_W26_republican_BIO
# GROWUPGUN2C_W26_republican_PORTRAY
# GROWUPGUN2C_W26_independent_QA
# GROWUPGUN2C_W26_independent_BIO
# GROWUPGUN2C_W26_independent_PORTRAY
# CRIMEVICTIM_W26_democrat_QA
# CRIMEVICTIM_W26_democrat_BIO
# CRIMEVICTIM_W26_democrat_PORTRAY
# CRIMEVICTIM_W26_republican_QA
# CRIMEVICTIM_W26_republican_BIO
# CRIMEVICTIM_W26_republican_PORTRAY
# CRIMEVICTIM_W26_independent_QA
# CRIMEVICTIM_W26_independent_BIO
# CRIMEVICTIM_W26_independent_PORTRAY
# GUNRESPNOKIDSF_W26_democrat_QA
# GUNRESPNOKIDSF_W26_democrat_BIO
# GUNRESPNOKIDSF_W26_democrat_PORTRAY
# GUNRESPNOKIDSF_W26_republican_QA
# GUNRESPNOKIDSF_W26_republican_BIO
# GUNRESPNOKIDSF_W26_republican_PORTRAY
# GUNRESPNOKIDSF_W26_independent_QA
# GUNRESPNOKIDSF_W26_independent_BIO
# GUNRESPNOKIDSF_W26_independent_PORTRAY
# GUNSAFE2_W26_democrat_QA
# GUNSAFE2_W26_democrat_BIO
# GUNSAFE2_W26_democrat_PORTRAY
# GUNSAFE2_W26_republican_QA
# GUNSAFE2_W26_republican_BIO
# GUNSAFE2_W26_republican_PORTRAY
# GUNSAFE2_W26_independent_QA
# GUNSAFE2_W26_independent_BIO
# GUNSAFE2_W26_independent_PORTRAY
# REASONGUNC_W26_democrat_QA
# REASONGUNC_W26_democrat_BIO
# REASONGUNC_W26_democrat_PORTRAY
# REASONGUNC_W26_republican_QA
# REASONGUNC_W26_republican_BIO
# REASONGUNC_W26_republican_PORTRAY
# REASONGUNC_W26_independent_QA
# REASONGUNC_W26_independent_BIO
# REASONGUNC_W26_independent_PORTRAY
# GROWUPGUN6_W26_democrat_QA
# GROWUPGUN6_W26_democrat_BIO
# GROWUPGUN6_W26_democrat_PORTRAY
# GROWUPGUN6_W26_republican_QA
# GROWUPGUN6_W26_republican_BIO
# GROWUPGUN6_W26_republican_PORTRAY
# GROWUPGUN6_W26_independent_QA
# GROWUPGUN6_W26_independent_BIO
# GROWUPGUN6_W26_independent_PORTRAY
# GUNCONTRIBF_W26_democrat_QA
# GUNCONTRIBF_W26_democrat_BIO
# GUNCONTRIBF_W26_democrat_PORTRAY
# GUNCONTRIBF_W26_republican_QA
# GUNCONTRIBF_W26_republican_BIO
# GUNCONTRIBF_W26_republican_PORTRAY
# GUNCONTRIBF_W26_independent_QA
# GUNCONTRIBF_W26_independent_BIO
# GUNCONTRIBF_W26_independent_PORTRAY
# GUNRESPKIDSB_W26_democrat_QA
# GUNRESPKIDSB_W26_democrat_BIO
# GUNRESPKIDSB_W26_democrat_PORTRAY
# GUNRESPKIDSB_W26_republican_QA
# GUNRESPKIDSB_W26_republican_BIO
# GUNRESPKIDSB_W26_republican_PORTRAY
# GUNRESPKIDSB_W26_independent_QA
# GUNRESPKIDSB_W26_independent_BIO
# GUNRESPKIDSB_W26_independent_PORTRAY
# GUNRESPNOKIDSB_W26_democrat_QA
# GUNRESPNOKIDSB_W26_democrat_BIO
# GUNRESPNOKIDSB_W26_democrat_PORTRAY
# GUNRESPNOKIDSB_W26_republican_QA
# GUNRESPNOKIDSB_W26_republican_BIO
# GUNRESPNOKIDSB_W26_republican_PORTRAY
# GUNRESPNOKIDSB_W26_independent_QA
# GUNRESPNOKIDSB_W26_independent_BIO
# GUNRESPNOKIDSB_W26_independent_PORTRAY
# WORRYF_W26_democrat_QA
# WORRYF_W26_democrat_BIO
# WORRYF_W26_democrat_PORTRAY
# WORRYF_W26_republican_QA
# WORRYF_W26_republican_BIO
# WORRYF_W26_republican_PORTRAY
# WORRYF_W26_independent_QA
# WORRYF_W26_independent_BIO
# WORRYF_W26_independent_PORTRAY
# GROWUPVIOL_W26_democrat_QA
# GROWUPVIOL_W26_democrat_BIO
# GROWUPVIOL_W26_democrat_PORTRAY
# GROWUPVIOL_W26_republican_QA
# GROWUPVIOL_W26_republican_BIO
# GROWUPVIOL_W26_republican_PORTRAY
# GROWUPVIOL_W26_independent_QA
# GROWUPVIOL_W26_independent_BIO
# GROWUPVIOL_W26_independent_PORTRAY
# DEFENDGUN_W26_democrat_QA
# DEFENDGUN_W26_democrat_BIO
# DEFENDGUN_W26_democrat_PORTRAY
# DEFENDGUN_W26_republican_QA
# DEFENDGUN_W26_republican_BIO
# DEFENDGUN_W26_republican_PORTRAY
# DEFENDGUN_W26_independent_QA
# DEFENDGUN_W26_independent_BIO
# DEFENDGUN_W26_independent_PORTRAY
# WORRYB_W26_democrat_QA
# WORRYB_W26_democrat_BIO
# WORRYB_W26_democrat_PORTRAY
# WORRYB_W26_republican_QA
# WORRYB_W26_republican_BIO
# WORRYB_W26_republican_PORTRAY
# WORRYB_W26_independent_QA
# WORRYB_W26_independent_BIO
# WORRYB_W26_independent_PORTRAY
# REASONGUNB_W26_democrat_QA
# REASONGUNB_W26_democrat_BIO
# REASONGUNB_W26_democrat_PORTRAY
# REASONGUNB_W26_republican_QA
# REASONGUNB_W26_republican_BIO
# REASONGUNB_W26_republican_PORTRAY
# REASONGUNB_W26_independent_QA
# REASONGUNB_W26_independent_BIO
# REASONGUNB_W26_independent_PORTRAY
# GUNACTIVITYE_W26_democrat_QA
# GUNACTIVITYE_W26_democrat_BIO
# GUNACTIVITYE_W26_democrat_PORTRAY
# GUNACTIVITYE_W26_republican_QA
# GUNACTIVITYE_W26_republican_BIO
# GUNACTIVITYE_W26_republican_PORTRAY
# GUNACTIVITYE_W26_independent_QA
# GUNACTIVITYE_W26_independent_BIO
# GUNACTIVITYE_W26_independent_PORTRAY
# EVEROWN_W26_democrat_QA
# EVEROWN_W26_democrat_BIO
# EVEROWN_W26_democrat_PORTRAY
# EVEROWN_W26_republican_QA
# EVEROWN_W26_republican_BIO
# EVEROWN_W26_republican_PORTRAY
# EVEROWN_W26_independent_QA
# EVEROWN_W26_independent_BIO
# EVEROWN_W26_independent_PORTRAY
# GROWUPGUN2A_W26_democrat_QA
# GROWUPGUN2A_W26_democrat_BIO
# GROWUPGUN2A_W26_democrat_PORTRAY
# GROWUPGUN2A_W26_republican_QA
# GROWUPGUN2A_W26_republican_BIO
# GROWUPGUN2A_W26_republican_PORTRAY
# GROWUPGUN2A_W26_independent_QA
# GROWUPGUN2A_W26_independent_BIO
# GROWUPGUN2A_W26_independent_PORTRAY
# GROWUPGUN7_W26_democrat_QA
# GROWUPGUN7_W26_democrat_BIO
# GROWUPGUN7_W26_democrat_PORTRAY
# GROWUPGUN7_W26_republican_QA
# GROWUPGUN7_W26_republican_BIO
# GROWUPGUN7_W26_republican_PORTRAY
# GROWUPGUN7_W26_independent_QA
# GROWUPGUN7_W26_independent_BIO
# GROWUPGUN7_W26_independent_PORTRAY
# GUNTYPEOWNC_W26_democrat_QA
# GUNTYPEOWNC_W26_democrat_BIO
# GUNTYPEOWNC_W26_democrat_PORTRAY
# GUNTYPEOWNC_W26_republican_QA
# GUNTYPEOWNC_W26_republican_BIO
# GUNTYPEOWNC_W26_republican_PORTRAY
# GUNTYPEOWNC_W26_independent_QA
# GUNTYPEOWNC_W26_independent_BIO
# GUNTYPEOWNC_W26_independent_PORTRAY
# GUNLOADED2_W26_democrat_QA
# GUNLOADED2_W26_democrat_BIO
# GUNLOADED2_W26_democrat_PORTRAY
# GUNLOADED2_W26_republican_QA
# GUNLOADED2_W26_republican_BIO
# GUNLOADED2_W26_republican_PORTRAY
# GUNLOADED2_W26_independent_QA
# GUNLOADED2_W26_independent_BIO
# GUNLOADED2_W26_independent_PORTRAY
# GROWUPGUN1_W26_democrat_QA
# GROWUPGUN1_W26_democrat_BIO
# GROWUPGUN1_W26_democrat_PORTRAY
# GROWUPGUN1_W26_republican_QA
# GROWUPGUN1_W26_republican_BIO
# GROWUPGUN1_W26_republican_PORTRAY
# GROWUPGUN1_W26_independent_QA
# GROWUPGUN1_W26_independent_BIO
# GROWUPGUN1_W26_independent_PORTRAY
# GUNCOURSES_W26_democrat_QA
# GUNCOURSES_W26_democrat_BIO
# GUNCOURSES_W26_democrat_PORTRAY
# GUNCOURSES_W26_republican_QA
# GUNCOURSES_W26_republican_BIO
# GUNCOURSES_W26_republican_PORTRAY
# GUNCOURSES_W26_independent_QA
# GUNCOURSES_W26_independent_BIO
# GUNCOURSES_W26_independent_PORTRAY
# MARGUN_W26_democrat_QA
# MARGUN_W26_democrat_BIO
# MARGUN_W26_democrat_PORTRAY
# MARGUN_W26_republican_QA
# MARGUN_W26_republican_BIO
# MARGUN_W26_republican_PORTRAY
# MARGUN_W26_independent_QA
# MARGUN_W26_independent_BIO
# MARGUN_W26_independent_PORTRAY
# GUNRESPKIDSE_W26_democrat_QA
# GUNRESPKIDSE_W26_democrat_BIO
# GUNRESPKIDSE_W26_democrat_PORTRAY
# GUNRESPKIDSE_W26_republican_QA
# GUNRESPKIDSE_W26_republican_BIO
# GUNRESPKIDSE_W26_republican_PORTRAY
# GUNRESPKIDSE_W26_independent_QA
# GUNRESPKIDSE_W26_independent_BIO
# GUNRESPKIDSE_W26_independent_PORTRAY
# GUNRESPKIDSG_W26_democrat_QA
# GUNRESPKIDSG_W26_democrat_BIO
# GUNRESPKIDSG_W26_democrat_PORTRAY
# GUNRESPKIDSG_W26_republican_QA
# GUNRESPKIDSG_W26_republican_BIO
# GUNRESPKIDSG_W26_republican_PORTRAY
# GUNRESPKIDSG_W26_independent_QA
# GUNRESPKIDSG_W26_independent_BIO
# GUNRESPKIDSG_W26_independent_PORTRAY
# GUNACCESS_W26_democrat_QA
# GUNACCESS_W26_democrat_BIO
# GUNACCESS_W26_democrat_PORTRAY
# GUNACCESS_W26_republican_QA
# GUNACCESS_W26_republican_BIO
# GUNACCESS_W26_republican_PORTRAY
# GUNACCESS_W26_independent_QA
# GUNACCESS_W26_independent_BIO
# GUNACCESS_W26_independent_PORTRAY
# GUNLOCKED1_W26_democrat_QA
# GUNLOCKED1_W26_democrat_BIO
# GUNLOCKED1_W26_democrat_PORTRAY
# GUNLOCKED1_W26_republican_QA
# GUNLOCKED1_W26_republican_BIO
# GUNLOCKED1_W26_republican_PORTRAY
# GUNLOCKED1_W26_independent_QA
# GUNLOCKED1_W26_independent_BIO
# GUNLOCKED1_W26_independent_PORTRAY
# SHOOTFREQ_W26_democrat_QA
# SHOOTFREQ_W26_democrat_BIO
# SHOOTFREQ_W26_democrat_PORTRAY
# SHOOTFREQ_W26_republican_QA
# SHOOTFREQ_W26_republican_BIO
# SHOOTFREQ_W26_republican_PORTRAY
# SHOOTFREQ_W26_independent_QA
# SHOOTFREQ_W26_independent_BIO
# SHOOTFREQ_W26_independent_PORTRAY
# GUNRESPNOKIDSC_W26_democrat_QA
# GUNRESPNOKIDSC_W26_democrat_BIO
# GUNRESPNOKIDSC_W26_democrat_PORTRAY
# GUNRESPNOKIDSC_W26_republican_QA
# GUNRESPNOKIDSC_W26_republican_BIO
# GUNRESPNOKIDSC_W26_republican_PORTRAY
# GUNRESPNOKIDSC_W26_independent_QA
# GUNRESPNOKIDSC_W26_independent_BIO
# GUNRESPNOKIDSC_W26_independent_PORTRAY
# GUNCOMMUNITY_W26_democrat_QA
# GUNCOMMUNITY_W26_democrat_BIO
# GUNCOMMUNITY_W26_democrat_PORTRAY
# GUNCOMMUNITY_W26_republican_QA
# GUNCOMMUNITY_W26_republican_BIO
# GUNCOMMUNITY_W26_republican_PORTRAY
# GUNCOMMUNITY_W26_independent_QA
# GUNCOMMUNITY_W26_independent_BIO
# GUNCOMMUNITY_W26_independent_PORTRAY
# NOCARRYGUN_W26_democrat_QA
# NOCARRYGUN_W26_democrat_BIO
# NOCARRYGUN_W26_democrat_PORTRAY
# NOCARRYGUN_W26_republican_QA
# NOCARRYGUN_W26_republican_BIO
# NOCARRYGUN_W26_republican_PORTRAY
# NOCARRYGUN_W26_independent_QA
# NOCARRYGUN_W26_independent_BIO
# NOCARRYGUN_W26_independent_PORTRAY
# GUNRESPKIDSH_W26_democrat_QA
# GUNRESPKIDSH_W26_democrat_BIO
# GUNRESPKIDSH_W26_democrat_PORTRAY
# GUNRESPKIDSH_W26_republican_QA
# GUNRESPKIDSH_W26_republican_BIO
# GUNRESPKIDSH_W26_republican_PORTRAY
# GUNRESPKIDSH_W26_independent_QA
# GUNRESPKIDSH_W26_independent_BIO
# GUNRESPKIDSH_W26_independent_PORTRAY
# GUNRESPKIDSD_W26_democrat_QA
# GUNRESPKIDSD_W26_democrat_BIO
# GUNRESPKIDSD_W26_democrat_PORTRAY
# GUNRESPKIDSD_W26_republican_QA
# GUNRESPKIDSD_W26_republican_BIO
# GUNRESPKIDSD_W26_republican_PORTRAY
# GUNRESPKIDSD_W26_independent_QA
# GUNRESPKIDSD_W26_independent_BIO
# GUNRESPKIDSD_W26_independent_PORTRAY
# GROWUPGUN4_W26_democrat_QA
# GROWUPGUN4_W26_democrat_BIO
# GROWUPGUN4_W26_democrat_PORTRAY
# GROWUPGUN4_W26_republican_QA
# GROWUPGUN4_W26_republican_BIO
# GROWUPGUN4_W26_republican_PORTRAY
# GROWUPGUN4_W26_independent_QA
# GROWUPGUN4_W26_independent_BIO
# GROWUPGUN4_W26_independent_PORTRAY
# WORRYC_W26_democrat_QA
# WORRYC_W26_democrat_BIO
# WORRYC_W26_democrat_PORTRAY
# WORRYC_W26_republican_QA
# WORRYC_W26_republican_BIO
# WORRYC_W26_republican_PORTRAY
# WORRYC_W26_independent_QA
# WORRYC_W26_independent_BIO
# WORRYC_W26_independent_PORTRAY
# GUNACTIVITYC_W26_democrat_QA
# GUNACTIVITYC_W26_democrat_BIO
# GUNACTIVITYC_W26_democrat_PORTRAY
# GUNACTIVITYC_W26_republican_QA
# GUNACTIVITYC_W26_republican_BIO
# GUNACTIVITYC_W26_republican_PORTRAY
# GUNACTIVITYC_W26_independent_QA
# GUNACTIVITYC_W26_independent_BIO
# GUNACTIVITYC_W26_independent_PORTRAY
# GUNLOCKED2_W26_democrat_QA
# GUNLOCKED2_W26_democrat_BIO
# GUNLOCKED2_W26_democrat_PORTRAY
# GUNLOCKED2_W26_republican_QA
# GUNLOCKED2_W26_republican_BIO
# GUNLOCKED2_W26_republican_PORTRAY
# GUNLOCKED2_W26_independent_QA
# GUNLOCKED2_W26_independent_BIO
# GUNLOCKED2_W26_independent_PORTRAY
# WORRYG_W26_democrat_QA
# WORRYG_W26_democrat_BIO
# WORRYG_W26_democrat_PORTRAY
# WORRYG_W26_republican_QA
# WORRYG_W26_republican_BIO
# WORRYG_W26_republican_PORTRAY
# WORRYG_W26_independent_QA
# WORRYG_W26_independent_BIO
# WORRYG_W26_independent_PORTRAY
# GUNSAFE_W26_democrat_QA
# GUNSAFE_W26_democrat_BIO
# GUNSAFE_W26_democrat_PORTRAY
# GUNSAFE_W26_republican_QA
# GUNSAFE_W26_republican_BIO
# GUNSAFE_W26_republican_PORTRAY
# GUNSAFE_W26_independent_QA
# GUNSAFE_W26_independent_BIO
# GUNSAFE_W26_independent_PORTRAY
# SAFECRIME_W26_democrat_QA
# SAFECRIME_W26_democrat_BIO
# SAFECRIME_W26_democrat_PORTRAY
# SAFECRIME_W26_republican_QA
# SAFECRIME_W26_republican_BIO
# SAFECRIME_W26_republican_PORTRAY
# SAFECRIME_W26_independent_QA
# SAFECRIME_W26_independent_BIO
# SAFECRIME_W26_independent_PORTRAY
# REASONGUNE_W26_democrat_QA
# REASONGUNE_W26_democrat_BIO
# REASONGUNE_W26_democrat_PORTRAY
# REASONGUNE_W26_republican_QA
# REASONGUNE_W26_republican_BIO
# REASONGUNE_W26_republican_PORTRAY
# REASONGUNE_W26_independent_QA
# REASONGUNE_W26_independent_BIO
# REASONGUNE_W26_independent_PORTRAY
# GUNCONTRIBE_W26_democrat_QA
# GUNCONTRIBE_W26_democrat_BIO
# GUNCONTRIBE_W26_democrat_PORTRAY
# GUNCONTRIBE_W26_republican_QA
# GUNCONTRIBE_W26_republican_BIO
# GUNCONTRIBE_W26_republican_PORTRAY
# GUNCONTRIBE_W26_independent_QA
# GUNCONTRIBE_W26_independent_BIO
# GUNCONTRIBE_W26_independent_PORTRAY
# GUNFRIEND_W26_democrat_QA
# GUNFRIEND_W26_democrat_BIO
# GUNFRIEND_W26_democrat_PORTRAY
# GUNFRIEND_W26_republican_QA
# GUNFRIEND_W26_republican_BIO
# GUNFRIEND_W26_republican_PORTRAY
# GUNFRIEND_W26_independent_QA
# GUNFRIEND_W26_independent_BIO
# GUNFRIEND_W26_independent_PORTRAY
# EVERSHOT_W26_democrat_QA
# EVERSHOT_W26_democrat_BIO
# EVERSHOT_W26_democrat_PORTRAY
# EVERSHOT_W26_republican_QA
# EVERSHOT_W26_republican_BIO
# EVERSHOT_W26_republican_PORTRAY
# EVERSHOT_W26_independent_QA
# EVERSHOT_W26_independent_BIO
# EVERSHOT_W26_independent_PORTRAY
# GUNRESPNOKIDSD_W26_democrat_QA
# GUNRESPNOKIDSD_W26_democrat_BIO
# GUNRESPNOKIDSD_W26_democrat_PORTRAY
# GUNRESPNOKIDSD_W26_republican_QA
# GUNRESPNOKIDSD_W26_republican_BIO
# GUNRESPNOKIDSD_W26_republican_PORTRAY
# GUNRESPNOKIDSD_W26_independent_QA
# GUNRESPNOKIDSD_W26_independent_BIO
# GUNRESPNOKIDSD_W26_independent_PORTRAY
# GUNCONTRIBD_W26_democrat_QA
# GUNCONTRIBD_W26_democrat_BIO
# GUNCONTRIBD_W26_democrat_PORTRAY
# GUNCONTRIBD_W26_republican_QA
# GUNCONTRIBD_W26_republican_BIO
# GUNCONTRIBD_W26_republican_PORTRAY
# GUNCONTRIBD_W26_independent_QA
# GUNCONTRIBD_W26_independent_BIO
# GUNCONTRIBD_W26_independent_PORTRAY
# WORRYA_W26_democrat_QA
# WORRYA_W26_democrat_BIO
# WORRYA_W26_democrat_PORTRAY
# WORRYA_W26_republican_QA
# WORRYA_W26_republican_BIO
# WORRYA_W26_republican_PORTRAY
# WORRYA_W26_independent_QA
# WORRYA_W26_independent_BIO
# WORRYA_W26_independent_PORTRAY
# GUNTHREAT_W26_democrat_QA
# GUNTHREAT_W26_democrat_BIO
# GUNTHREAT_W26_democrat_PORTRAY
# GUNTHREAT_W26_republican_QA
# GUNTHREAT_W26_republican_BIO
# GUNTHREAT_W26_republican_PORTRAY
# GUNTHREAT_W26_independent_QA
# GUNTHREAT_W26_independent_BIO
# GUNTHREAT_W26_independent_PORTRAY
# GUNRESPNOKIDSE_W26_democrat_QA
# GUNRESPNOKIDSE_W26_democrat_BIO
# GUNRESPNOKIDSE_W26_democrat_PORTRAY
# GUNRESPNOKIDSE_W26_republican_QA
# GUNRESPNOKIDSE_W26_republican_BIO
# GUNRESPNOKIDSE_W26_republican_PORTRAY
# GUNRESPNOKIDSE_W26_independent_QA
# GUNRESPNOKIDSE_W26_independent_BIO
# GUNRESPNOKIDSE_W26_independent_PORTRAY
# IMPREASONGUN_W26_democrat_QA
# IMPREASONGUN_W26_democrat_BIO
# IMPREASONGUN_W26_democrat_PORTRAY
# IMPREASONGUN_W26_republican_QA
# IMPREASONGUN_W26_republican_BIO
# IMPREASONGUN_W26_republican_PORTRAY
# IMPREASONGUN_W26_independent_QA
# IMPREASONGUN_W26_independent_BIO
# IMPREASONGUN_W26_independent_PORTRAY
# GUN_W26_democrat_QA
# GUN_W26_democrat_BIO
# GUN_W26_democrat_PORTRAY
# GUN_W26_republican_QA
# GUN_W26_republican_BIO
# GUN_W26_republican_PORTRAY
# GUN_W26_independent_QA
# GUN_W26_independent_BIO
# GUN_W26_independent_PORTRAY
# GUNKILLF2_W26_democrat_QA
# GUNKILLF2_W26_democrat_BIO
# GUNKILLF2_W26_democrat_PORTRAY
# GUNKILLF2_W26_republican_QA
# GUNKILLF2_W26_republican_BIO
# GUNKILLF2_W26_republican_PORTRAY
# GUNKILLF2_W26_independent_QA
# GUNKILLF2_W26_independent_BIO
# GUNKILLF2_W26_independent_PORTRAY
# NEVEROWN_W26_democrat_QA
# NEVEROWN_W26_democrat_BIO
# NEVEROWN_W26_democrat_PORTRAY
# NEVEROWN_W26_republican_QA
# NEVEROWN_W26_republican_BIO
# NEVEROWN_W26_republican_PORTRAY
# NEVEROWN_W26_independent_QA
# NEVEROWN_W26_independent_BIO
# NEVEROWN_W26_independent_PORTRAY
# GUNRESPNOKIDSG_W26_democrat_QA
# GUNRESPNOKIDSG_W26_democrat_BIO
# GUNRESPNOKIDSG_W26_democrat_PORTRAY
# GUNRESPNOKIDSG_W26_republican_QA
# GUNRESPNOKIDSG_W26_republican_BIO
# GUNRESPNOKIDSG_W26_republican_PORTRAY
# GUNRESPNOKIDSG_W26_independent_QA
# GUNRESPNOKIDSG_W26_independent_BIO
# GUNRESPNOKIDSG_W26_independent_PORTRAY
# GUNCONTRIBB_W26_democrat_QA
# GUNCONTRIBB_W26_democrat_BIO
# GUNCONTRIBB_W26_democrat_PORTRAY
# GUNCONTRIBB_W26_republican_QA
# GUNCONTRIBB_W26_republican_BIO
# GUNCONTRIBB_W26_republican_PORTRAY
# GUNCONTRIBB_W26_independent_QA
# GUNCONTRIBB_W26_independent_BIO
# GUNCONTRIBB_W26_independent_PORTRAY
# GROWUPGUN2B_W26_democrat_QA
# GROWUPGUN2B_W26_democrat_BIO
# GROWUPGUN2B_W26_democrat_PORTRAY
# GROWUPGUN2B_W26_republican_QA
# GROWUPGUN2B_W26_republican_BIO
# GROWUPGUN2B_W26_republican_PORTRAY
# GROWUPGUN2B_W26_independent_QA
# GROWUPGUN2B_W26_independent_BIO
# GROWUPGUN2B_W26_independent_PORTRAY
# GUNCONTRIBC_W26_democrat_QA
# GUNCONTRIBC_W26_democrat_BIO
# GUNCONTRIBC_W26_democrat_PORTRAY
# GUNCONTRIBC_W26_republican_QA
# GUNCONTRIBC_W26_republican_BIO
# GUNCONTRIBC_W26_republican_PORTRAY
# GUNCONTRIBC_W26_independent_QA
# GUNCONTRIBC_W26_independent_BIO
# GUNCONTRIBC_W26_independent_PORTRAY
# GUNACTIVITYB_W26_democrat_QA
# GUNACTIVITYB_W26_democrat_BIO
# GUNACTIVITYB_W26_democrat_PORTRAY
# GUNACTIVITYB_W26_republican_QA
# GUNACTIVITYB_W26_republican_BIO
# GUNACTIVITYB_W26_republican_PORTRAY
# GUNACTIVITYB_W26_independent_QA
# GUNACTIVITYB_W26_independent_BIO
# GUNACTIVITYB_W26_independent_PORTRAY
# REASONGUNA_W26_democrat_QA
# REASONGUNA_W26_democrat_BIO
# REASONGUNA_W26_democrat_PORTRAY
# REASONGUNA_W26_republican_QA
# REASONGUNA_W26_republican_BIO
# REASONGUNA_W26_republican_PORTRAY
# REASONGUNA_W26_independent_QA
# REASONGUNA_W26_independent_BIO
# REASONGUNA_W26_independent_PORTRAY
# GUNCONTRIBA_W26_democrat_QA
# GUNCONTRIBA_W26_democrat_BIO
# GUNCONTRIBA_W26_democrat_PORTRAY
# GUNCONTRIBA_W26_republican_QA
# GUNCONTRIBA_W26_republican_BIO
# GUNCONTRIBA_W26_republican_PORTRAY
# GUNCONTRIBA_W26_independent_QA
# GUNCONTRIBA_W26_independent_BIO
# GUNCONTRIBA_W26_independent_PORTRAY
# GUNRESPKIDSA_W26_democrat_QA
# GUNRESPKIDSA_W26_democrat_BIO
# GUNRESPKIDSA_W26_democrat_PORTRAY
# GUNRESPKIDSA_W26_republican_QA
# GUNRESPKIDSA_W26_republican_BIO
# GUNRESPKIDSA_W26_republican_PORTRAY
# GUNRESPKIDSA_W26_independent_QA
# GUNRESPKIDSA_W26_independent_BIO
# GUNRESPKIDSA_W26_independent_PORTRAY
# GUNRESPKIDSC_W26_democrat_QA
# GUNRESPKIDSC_W26_democrat_BIO
# GUNRESPKIDSC_W26_democrat_PORTRAY
# GUNRESPKIDSC_W26_republican_QA
# GUNRESPKIDSC_W26_republican_BIO
# GUNRESPKIDSC_W26_republican_PORTRAY
# GUNRESPKIDSC_W26_independent_QA
# GUNRESPKIDSC_W26_independent_BIO
# GUNRESPKIDSC_W26_independent_PORTRAY
# GUNIDENTITY_W26_democrat_QA
# GUNIDENTITY_W26_democrat_BIO
# GUNIDENTITY_W26_democrat_PORTRAY
# GUNIDENTITY_W26_republican_QA
# GUNIDENTITY_W26_republican_BIO
# GUNIDENTITY_W26_republican_PORTRAY
# GUNIDENTITY_W26_independent_QA
# GUNIDENTITY_W26_independent_BIO
# GUNIDENTITY_W26_independent_PORTRAY
# WORLDDANGER_W26_democrat_QA
# WORLDDANGER_W26_democrat_BIO
# WORLDDANGER_W26_democrat_PORTRAY
# WORLDDANGER_W26_republican_QA
# WORLDDANGER_W26_republican_BIO
# WORLDDANGER_W26_republican_PORTRAY
# WORLDDANGER_W26_independent_QA
# WORLDDANGER_W26_independent_BIO
# WORLDDANGER_W26_independent_PORTRAY
# GUNRESPNOKIDSA_W26_democrat_QA
# GUNRESPNOKIDSA_W26_democrat_BIO
# GUNRESPNOKIDSA_W26_democrat_PORTRAY
# GUNRESPNOKIDSA_W26_republican_QA
# GUNRESPNOKIDSA_W26_republican_BIO
# GUNRESPNOKIDSA_W26_republican_PORTRAY
# GUNRESPNOKIDSA_W26_independent_QA
# GUNRESPNOKIDSA_W26_independent_BIO
# GUNRESPNOKIDSA_W26_independent_PORTRAY
# CARRYGUN_W26_democrat_QA
# CARRYGUN_W26_democrat_BIO
# CARRYGUN_W26_democrat_PORTRAY
# CARRYGUN_W26_republican_QA
# CARRYGUN_W26_republican_BIO
# CARRYGUN_W26_republican_PORTRAY
# CARRYGUN_W26_independent_QA
# CARRYGUN_W26_independent_BIO
# CARRYGUN_W26_independent_PORTRAY
